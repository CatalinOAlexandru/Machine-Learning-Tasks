# %% [markdown]
# # Neural Network Classifier
#
# In this assignment, your task is to train a type of Neural network classifier on the synthetic dataset that was also used in previous assignements. Please read the assignment entirely before you start coding. Most of the code that implements the neural network functionalities are provided to you. What you are expected to do is fill in certain missing parts that are required and then train two different networks and visualize the estimated posterior.
#
# - <a href='#non-linear-activation-functions'>Question 1</a> (10%) Fill in the code to
# implement the `sigmoid` and `relu` functions and their derivatives. Then, plot all four
# functions to verify that your implementation is correct. See the provided example first.
# - <a href='#the-neural-network'>Question 2</a> (80%) Fill in the code inside the
# `NeuralNetwork` class where necessary.
#     - <a href='#feedforward1'>a.</a> First, complete the code in the `feedforward` method of the `NeuralNetwork` class. Assuming that the input of the $l$-th layer of the network is $a^{l-1}$ ($a^{l-1}$ can be the non-linear output or activation of a previous layer or initially the input feature vector) then the linear-output of the layer is: $$z^{l}=W a^{l-1} + b$$ Then the non-linear output or "activation" is $a^{l} = f(z^{l})$ where $f(\cdot)$ is the non-linear activation function of the layer, applied element-wise on $z^{l}$. In our case, $f(\cdot)$ is either a `sigmoid` or `relu` function.
#     - <a href='#feedforward2'>b.</a> In the `feedforward` method of the `NeuralNetwork` class, write the code that implements the softmax function (see pages 67, 73 of the course slides). If $z^{L}$ is the linear-output of the output layer of the network then applying the softmax function on each of its elements $z^{L}_k$ is described by:
#
#     $$ softmax(z_k) = \frac{\exp(z^{L}_k)}{\sum_{k}\exp(z^{L}_k)}, k=0,...,C-1$$
# Note: $z^{L}$ will be a 2-dimensional vector as our synthetic dataset has $C=2$ classes. Consequently $softmax(z^{L}_{0}) = P_{estimated}(y=0 \mid x)$ and $softmax(z^{L}_{1}) = P_{estimated}(y=1 \mid x)$.
#     - <a href='#loss_function'>c.</a> Fill in the `loss_function` method of the `
#     NeuralNetwork` class so that it computes the value of the loss used to train the network (see page 68 of the coures slides, where it is refered to as "optimization criterion"):
# $$L(W) = - \sum_{i=1}^{N} \sum_{c=0}^{1} y_{c}^{i} \log (g_{c}(x^{i}; W))$$
# where $i$ indexes training examples, $c$ indexes the two classes {0,1} of our synthetic
# data, $W$ is the set of weights of the network and $g_{c}$ is the posterior of class $c$ as
# computed by the network. As implied in pages 68 and 70 of the course slides, for $y^{i}$
# being the true class label of example $x^{i}$, $y_{c}^{i}$ is the one-hot label encoding of
# $y^{i}$, meaning that $y_{c}^{i}=1$ if $y^{i}=c$ and $y_{c}^{i}=0$ if $y^{i} \neq c$. Use
# the gradient checking code (found <a href='#checking'>here</a>) to ensure all your additions
# to the `NeuralNetwork` class are working correctly.
#     - <a href='#backprop'>d.</a> Go through and try to understand the `backprop` method of
# the `Neural Network` class which is provided. Briefly explain what is done by the for
# loop at the end of the `backprop` method. Add your explanation in a markdown cell which <a href='#backprop'>here</a>.
# - <a href='#Train-networks'>Question 3</a> (10%) Use the `NeuralNetwork` class to define and train two different neural networks.
#     - <a href='#Define-Network'>a.</a> Train a network with a sigmoid non-linear activation
#     function. Then plot the accuracy and error curves. Finally, visualize the estimated
#     posterior. The code needed is provided.
#     - <a href='#Train2'>b.</a> By using the previous question's code as an example, train a
#  network with relu non-linear activation functions. Then with the provided code, plot the accuracy and error
#  curves and visualize the estimated posterior. Briefly  compare the performance of the two
#  networks in a markdown cell which must be added at the end of this notebook <a href='#Compare'>here</a>.

# %% [markdown]
# # Code
#
# ## Imports

# %%
import h5py
import matplotlib.pyplot as plt
import numpy as np
import pickle
from numpy.random import RandomState
from construct_data import construct_data
from gradientChecking import checkNNGradients, compute_numerical_gradient

# %% [markdown]
# ## Data Generation - Visualization

# %%
prng = RandomState(1)

# %matplotlib inline
plt.rcParams['figure.figsize'] = (5.0, 4.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

features, labels, posterior = construct_data(300, 'train', 'nonlinear', plusminus=False)

# Extract features for both classes
features_pos = features[labels == 1]
features_neg = features[labels != 1]

# Display data
fig = plt.figure(figsize=plt.figaspect(0.3))
ax = fig.add_subplot(1, 2, 1)
ax.scatter(features_pos[:, 0], features_pos[:, 1], c="red", label="Positive class")
ax.scatter(features_neg[:, 0], features_neg[:, 1], c="blue", label="Negative class")

ax.set_title("Training data")
ax.set_xlabel("Feature 1")
ax.set_ylabel("Feature 2")
ax.legend()

ax = fig.add_subplot(1, 2, 2)
ax.imshow(posterior, extent=[0, 1, 0, 1], origin='lower')
ax.set_title("Posterior of the positive class $P(y=1 \mid x)$")
ax.set_xlabel("Feature 1")
ax.set_ylabel("Feature 2")

plt.show()

# Our dataset arrays are modified to have a more convenient format for this assignement 
# instead of two arrays features (300,2) and labels (300,)
# we now have a list of 300 elements called data 
# each element of data is a tuple (x,y) 
# where x is  a (2,1) feature vector and y is a scalar label with value either 0 or 1 
data = []
for x, y in zip(features, labels): # creating alternative input
    x = x[:, np.newaxis]
    data.append(np.array([x,y]))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:41: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %% [markdown]
# ## Helper function for visualizing the posterior

# %%
def visualize_posterior(nnet):
    x_rng = y_rng = np.linspace(0, 1, 50)
    gridx, gridy = np.meshgrid(x_rng, y_rng)
    p_estimated_class1 = np.zeros((50, 50))
    for i in range(50):
        for j in range(50):
            v = np.array([gridx[i, j], gridy[i, j]])
            v = v[:, np.newaxis]
            out, _, _ = nnet.feedforward(v)
            p_estimated_class1[i, j] = out[1]

    fig = plt.figure(figsize=plt.figaspect(0.2))
    ax1 = fig.add_subplot(1, 3, 1)
    ax1.imshow(p_estimated_class1, extent=[0, 1, 0, 1], origin='lower')
    ax1.set_title("Estimated $P(y=1 \mid x)$")
    ax1.set_xlabel("Feature 1")
    ax1.set_ylabel("Feature 2")

    ax1 = fig.add_subplot(1, 3, 2)
    ax1.imshow(posterior, extent=[0, 1, 0, 1], origin='lower')
    ax1.set_title("Ground Truth of the positive class $")
    ax1.set_xlabel("Feature 1")
    ax1.set_ylabel("Feature 2")

    ax1 = fig.add_subplot(1, 3, 3)
    ax1.imshow(posterior-p_estimated_class1+1, extent=[0, 1, 0, 1], origin='lower')
    ax1.set_title("Difference between the ground truth and estimated posterior")
    ax1.set_xlabel("Feature 1")
    ax1.set_ylabel("Feature 2")
    plt.show()  
    
def visualize_cost_accuracy_curves(accuracy_training, cost_training):
    # Plots the cost and accuracy evolution during training 
    fig = plt.figure(figsize=plt.figaspect(0.2))
    ax1 = fig.add_subplot(1, 2, 1)
    ax1.plot(cost_training,'r')
    ax1.set_xlabel('epoch')
    ax1.set_ylabel('Cost')
    ax2 = fig.add_subplot(1, 2, 2)
    ax2.plot(accuracy_training)
    ax2.set_xlabel('epoch')
    ax2.set_ylabel('Accuracy')
    A = np.array(accuracy_training)
    best_epoch = np.argmax(A)
    print('best_accuracy:', max(accuracy_training), 'achieved at epoch:', best_epoch)

# %% [markdown]
# ## Analytical Derivative of a Function
# Here we present an example of how we can define (and visualize) each nonlinear function and its derivative. Let us consider the function $f(x)=x^2$. Analytically we know that $f'(x)=2 x$. Thus for some x we can analytically calculate the derivative of x. The following python functions compute $f$ and $f'$.

# %%
def square(x):
    f = x**2
    return f

def square_gradient(x):
    f_prime = 2*x
    return f_prime

# %% [markdown]
# We can visualize the function and its derivative using the following commands

# %%
fig = plt.figure(figsize=plt.figaspect(0.3))
ax = fig.add_subplot(1, 2, 1)
x = np.arange(-4, 4, 0.01)
f = square(x)
ax.plot(x, f)
f_prime = square_gradient(x)
ax.plot(x, f_prime)
ax.set_xlabel('x')
ax.set_ylabel('f')
# Out:
# Text(0, 0.5, 'f')

# %% [markdown]
# <a id='non-linear-activation-functions'></a>
# # Question 1
# ## Non-linear activation functions
# Fill in the functions that implement the non-linear functions which are used to produve the
# activations of the neurons of a neural network. Remember that for if $\sigma(x)$ is the
# sigmoid function, its derivative is $\sigma'(x)=\sigma(x)*(1-\sigma(x))$. Finally if
# $relu(x)=max(0,x)$ then $relu'(x>0)= 1$ and $relu'(x<=0)=0$.
# #### Note: Do not change the functions and their arguments!

# %%
# TO DO (Q1) 
def sigmoid(z):
    g = 1/(1+np.exp(-z))
    return g

def sigmoid_gradient(z): 
    sig = sigmoid(z) # getting the sigmoid value
    g = sig*(1-sig) # derivative of sigmoid
    return g
# /TO DO (Q1)

# TO DO (Q1)
def relu(x):
    g = np.maximum(0,x)
    # print("returning relu")
    return g

def relu_gradient(z):
    # 1 for x>0 and 0 for x<0
    g = 1 * (z>0)
    return g
# /TO DO (Q1)

# %% [markdown]
# ##### Visualize the functions and their gradients by plotting their output in the [-6,6] interval:

# %%
#TO DO (Q1)

# x as in your example
x = np.arange(-6, 6, 0.1)

# Sigmoid
sig = sigmoid(x)
sigGrad = sigmoid_gradient(x)

# Relu
relu = relu(x)
reluGrad = relu_gradient(x)


# Plotting
fig, axis = plt.subplots(1, 2, figsize = (15,5))

plt.subplot(1, 2, 1)
plt.title("Sigmoid / Gradient") 
plt.xlabel("x") 
plt.ylabel("g") 
plt.plot(x, sig) 
plt.plot(x, sigGrad) 

plt.subplot(1, 2, 2)
plt.title("Relu / Gradient") 
plt.xlabel("x") 
plt.ylabel("g") 
plt.plot(x, relu) 
plt.plot(x, reluGrad) 

plt.show()

# /TO DO (Q1)

# %% [markdown]
# # Question 2
# <a id='the-neural-network'></a>
# ## The Neural Network Class
#
# In this assignement, in order to define, train and use a neural network you are first required to complete the implementation provided below. Every operation related to the network is defined as a method (e.g. `feedforward` , `backpropagation`, etc.) of the `NeuralNetwork` class. You only need to complete the code inside the `feedforward` and `loss_function` methods.
#
# Go through the code to identify what each method inside the class does. Note that when first creating a `NeuralNetwork` class instance (for example as <a href='#Define-Network'> here</a>), the `__init__` method is executed and randomly initializes the network's weights, which then constitute an attribute of that instance. These weights are then modified by calling the `gradient_descent` method used to train the network.

# %%
class NeuralNetwork(object):
    # For Question 2 first focus on __init__ and feedforward
    def __init__(self, nnodes, activation_functions='sigmoid'):
        # nnodes: number of hidden units per layer  - e.g. [2,5,10] indicates a three-layer network with the respective number of nodes
        self.num_layers = len(nnodes)
        # weights, biases: list of the numpy arrays containing model parameters for linear layers
        # sampled originally from a gaussian distribution
        self.sizes = nnodes
        prng = RandomState(2)
        self.biases = [prng.randn(y, 1) for y in nnodes[1:]]
        self.weights = [prng.randn(y, x) for x, y in zip(nnodes[:-1], nnodes[1:])]       
        # non-linearity, specified when the network is initialized 
        self.activation_functions = activation_functions
        self.losses = []  # stores the losses during training
        self.accuracies = []  # stores the accuracies during training 
        self.epoch_best = 0 # epoch during training when accuracy was max
        
    def feedforward(self, x):
        # Computes and returns the output of the network for a given input x
        # In our case x.shape = (2,1), i.e. the input is a 2-dimensional vector
        # It also returns intermediate linear and non-linear outputs of the layers 
        # that can are for backpropagation when traning
        activations = [] # here we store the non-linear outputs of layers
        activations.append(x)
        zs = [] # here we store linear-outputs of layers
        
        # feedforward computation through all layers except the output layer
        for l in range(len(self.weights)-1):
            b = self.biases[l]
            w = self.weights[l]

            ##### TO DO Q2 linear output ##### 
            z = np.dot(w,x)+b
            ##### /TO DO Q2 linear output #####

            if self.activation_functions == 'sigmoid':
            ##### TO DO Q2 sigmoid ##### 
                activation = sigmoid(z)
            ##### /TO DO Q2 sigmoid #####

            elif self.activation_functions == 'relu':   
            ##### TO DO Q2 relu ##### 
                activation = relu(z)
            ##### /TO DO Q2 relu #####
            

            # save z values for backprop (linear output of each layer)
            zs.append(z) 
            # save activations for backprop (non-linear output of each layer)
            activations.append(activation)
            # the input at the next layer is the activation of the previous layer
            x = activation  
            
        # feedforward computation through the output layer
        w = self.weights[-1]
        b = self.biases[-1]
        z = np.dot(w, x) + b # linear-output of output-layer
        
        ##### /TO DO Q2 softmax #####
        softmax_output = np.exp(z)/sum(np.exp(z))
        ##### /TO DO Q2 softmax #####

        activations.append(softmax_output)
        zs.append(z)
        return softmax_output, zs, activations
    
    def loss_function(self,X):
        # computes the cross entropy cost 
        # X is a list, each element of which is a tuple (x,y) 
        # where x is the input and y is the ground truth label
        # x has shape (2,1) and y is a scalar
        
        loss = 0 # initializing cost as 0
        for x, y in X: # looping elements of list X, each element is a pair x,y 
            # Note: y is a scalar with value either 0 or 1
            # Note: The cost formula requires a one-hot encoded version of y
            
            ##### /TO DO Q2 cost function #####
            
            # step 1 feedforward computation
            softmax_output, zs, activations = self.feedforward(x)
            # step 2 cost value computation using x,y 

            cost  = -int(y == 0) * np.log(softmax_output[0]) + int(1-y == 0) * np.log(1-softmax_output[0])  
            cost += -int(y == 1) * np.log(softmax_output[1]) + int(1-y == 1) * np.log(1-softmax_output[1]) 

            # m = y.size
            # log_likelihood = -np.log(softmax_output[range(m),y])
            # cost = np.sum(log_likelihood) / m


            # step 3 increment total_cost 
            loss += cost
            
            ##### /TO DO Q2 cost function #####
            
        return loss 

    
    def gradient_descent(self, training_data, epochs, lr, test_data=None):
        # training_data is a list of tuples ([x1,x2],y) where y is the class and [x1,x2] is numpy array
        # lr is the learning_rate, it is scalar
        # epochs is a scalar value for the number of times the network 
        # is going to update its parameters after computing the gradient 
        # using all training examples
        
        n_train = len(training_data)
        accuracy_max = 0.0
        for j in range(epochs):
            # compute gradient using backprop and do gradient descent step to update params
            self.update_params(training_data, lr) 
            # compute loss value 
            loss = self.loss_function(training_data)
            # save loss value for visualization 
            self.losses.append(loss/n_train)
            if test_data:
                n_test = len(test_data)
                correct = self.evaluate(test_data)
                print ("Epoch {0}: Accuracy {1} / {2} loss: {3}".format(j, correct, n_test, loss/len(training_data)))
                accucary = correct / n_test
                self.accuracies.append(accucary)
                # if accuracy increased then store params 
                if accucary >= accuracy_max:
                    accuracy_max = accucary
                    w_best = self.weights
                    b_best = self.biases
                    epoch_best = j
                    # print('improved accuracy @ {}, {}'.format(j, accuracy_max))
            else:
                print ("No test_data given")
        if test_data:
            print('Model with highest accuracy {} achieved at epoch {}'.format(accuracy_max, epoch_best))
            # restore the weights and biases of the model with the highest accuracy
            self.weights = w_best 
            self.biases = b_best
            self.epoch_best = epoch_best
                
    def update_params(self, X, lr):
        # X is all the training data
        # X contains pairs (x,y) where x is the feature vector and y its class label
        N = len(X)
        grad_b = [np.zeros(b.shape) for b in self.biases]
        grad_w = [np.zeros(w.shape) for w in self.weights]
        #Gradient Descent parameter updates
        for x, y in X:
            delta_grad_b, delta_grad_w = self.backprop(x, y) # take an example backpropagate to find the gradients
            grad_b = [nb+dnb for nb, dnb in zip(grad_b, delta_grad_b)] # accumulate gradients for biases
            grad_w = [nw+dnw for nw, dnw in zip(grad_w, delta_grad_w)] # accumulate gradients for weights
        
        # Update the weights and biases using the gradient of the cost computed using the whole training_dataset
        # divide by N to scale the overall gradient by the number of training examples
        self.weights = [w-lr*nw/N for w, nw in zip(self.weights, grad_w)]  
        self.biases = [b-lr*nb/N for b, nb in zip(self.biases,  grad_b)]
        
        
    def backprop(self, x, y):
        #Returns (grad_b, grad_w) representing the
        #gradients for the cost function  wrt b and w, initialized as zeros 
        grad_b = [np.zeros(b.shape) for b in self.biases]
        grad_w = [np.zeros(w.shape) for w in self.weights]

        ######### Forward pass #########
        dummy, zs, activations= self.feedforward(x) 
        
        # one hot encoding of the true class label y
        # if y=1 then the one-hot encoding of y is y =[0, 1]
        # if y=0 then the one-hot encoding of y is y =[1, 0]
        if y == 0:
            y_one_hot = np.array([[1], [0]])
        else:
            y_one_hot = np.array([[0], [1]])
        
        ######## Backward pass ##########        
        # Grad at the ouput layer 
        
        dL_dz = activations[-1] - y_one_hot  # dL/dz (slide 51 derives this)
        # also this is the δ of slide 63 i.e the sensitivity of the loss to the activations of output layer
        
        # grad wrt the parameters (w,b) of the output layer     
        # for the grad of the loss wrt to the bias we have:
        # Given z = Wa + b  (we omit z(l) and a(l-1) for simplicity)
        # Chain_rule: dL_db = dL_dz * dz_db = dL_dz * 1 = dL_dz 
        grad_b[-1] = dL_dz  
        
        # for the grad of the loss wrt to the weight matrix with elements Wij we have:
        # dL_dWij = dL_dzi * dz[i]_dWij = dL_dz[i] * a[j]
        # which can be written as the following dot product 
        
        grad_w[-1] = np.dot(dL_dz, activations[-2].T)
        # Note: the resulting shape of grad_w[-1] is (2, num nodes of previous layer)
        # which is exactly the shape of the weight matrix mapping of the output layer 
        
        # By uncommenting the following lines the you can printing the shapes 
        # of each variable used to compute the gradient at the output layer
        '''
        print('---- shapes')
        print('output-layer')
        print('activation',activations[-1].shape) 
        print('z', zs[-1].shape)
        print('dL_dz',dL_dz.shape)
        print('grad_b:',grad_b[-1].shape,' grad_w:',grad_w[-1].shape)
        '''
        ############# TO DO Q2b explain what is done by following for loop###############
        
        # Grad at previous layers
        delta = dL_dz # delta of output layer
        L = self.num_layers # considering input layer + hidden layers + output layer
        # zs has L-1 elements , activations has L elements , self.weights of L-1 elements
        # start from 2nd-to-last layer (hence the L-2 index) and move backwards 
        for l in range(L-2, 0, -1): 
            # z is the linear output of the l-th layer
            z = zs[l-1] 
            
            # activation if the activation of the (l-1)-th layer
            activation=activations[l-1] 
            
            # weights that map the output of the 
            # l-th layer to the input of the (l+1)-th layer
            weights=self.weights[l] 
            
            # compute the value of the gradient of the non-linear function of the l-th layer 
            # evaluated at z: act_g = f'(z) 
            if self.activation_functions=='relu': act_g = relu_gradient(z)
            elif self.activation_functions=='sigmoid': act_g = sigmoid_gradient(z)
            
            # backpropagate delta from (l+1)-th layer to l-th layer
            prod  = np.dot(weights.T, delta)    
    
            delta = prod * act_g
            
            # gradients wrt to the parameters of the l-th layer
            grad_b[l-1] = delta 
            grad_w[l-1] = np.dot(delta, activation.T) 
            
            # By uncommenting the following lines the function 
            # will be printing the shapes of each variable             
            '''
            print('---- shapes')
            print('layer:',l)  
            print('activation ',activation.shape)
            print('z ', z.shape)
            print('w ',weights.shape)       
            print('prod ',prod.shape,'act_g',act_g.shape)
            print('delta ',delta.shape)
            print('grad_b ',grad_b[-l].shape,' grad_w ',grad_w[-l].shape) 
            '''
        return (grad_b, grad_w)
        ############# TO DO Q2b explain what is done by above for loop###############

    def evaluate(self, data):
        correct = 0
        for x, y in data:
            # we do not need to save activations and zs when classifying data 
            # we only care about the outupt 
            output, _, _ = self.feedforward(x)
            # predicted class is the index in the ouptut with maximal propability
            correct = correct + int(y == np.argmax(output))
        return correct

# %% [markdown]
# <a id='backprop'></a>
# ## Explanation of the backprop for loop

# %% [markdown]
# Answer:

# %% [markdown]
# <a id='checking'></a>
# ## Gradient checking:
# We are going to use $gradient$ $checking$ to check if the numerical (using approximations)
# and analytical (computed by our backprop implementation) gradient computations match. To
# test that we are going to check the gradients computed for a small neural network.
# Suppose we have a neural network with 2 dimensional inputs , 2 hidden layers of 4 neurons
# each with sigmoid non-linearities and an output layer of 2 neurons with sigmoid non-
# linearity. This network is initialized as shown by the code in the next cell.

# %%
nnodes2 = [2, 4, 4, 2]
activation_functions2 = 'relu' 
nnet_checking = NeuralNetwork(nnodes2, activation_functions2)

# %% [markdown]
# We are going to use a few training examples (m=50) to check if the analytical and numerical gradients match.

# %%
m = 50 # using 50 examples to do gradient checking 
train_data = data[1:m] 
checkNNGradients(nnet_checking, train_data)  # compute_numerical_gradient
# Out:
# Relative difference 0.9999999476450825 for layer 0 parameters
# error with backprop
# Relative difference 0.9999999988042718 for layer 1 parameters
# error with backprop
# Relative difference 0.9999999529802549 for layer 2 parameters
# error with backprop

# %% [markdown]
# # Question 3
# <a id='Define-Network'></a>
# ## Define a Network
# To initialize a Neural Network we must provide two arguments: $nnodes$ and activation_functions. $nnodes$ is a list. Each element of $nnodes$ defines the number of neurons of each layer of the network. By convention the first element of $nnodes$ defines the dimensionality of the input layer of the network that is not associated with any weights and biases (i.e if the input to a network is $x \in R^{2}$ then the dimensionality of the input layer is $2$). The rest of the elements of $nnodes$ are used to initialize the weigths and biases of the hidden layers and the output layer. The activation_functions argument is a string that defines the type of non-linear function to be used for each neuron of the hidden layer. Our implementation supports relu and sigmoid as non-linear activation functions.

# %%
nnodes = [2, 10, 10, 2]
activation_functions = 'sigmoid' # this can either be 'sigmoid' or 'relu'
nnet = NeuralNetwork(nnodes, activation_functions) # creating a NeuralNetwork instance
# accessing the weights attribute of the nnet instance we can print weight shapes per layer
print(['layer {}: w {}'.format(layer, w.shape) for w, layer in zip(nnet.weights, range(len(nnet.weights)))])
# Out:
# ['layer 0: w (10, 2)', 'layer 1: w (10, 10)', 'layer 2: w (2, 10)']

# %% [markdown]
# ## Train a network with sigmoid activation functions.
# Note that for each training epoch we compute the mean cost and accuracy on the training set.
# Once the training is completed visualize the cost / accuracy curves and the estimated posterior using the provided code. It is recomended that you keep the learning rate and number of epochs as provided below.

# %%
learning_rate = 2
epochs = 5000  # usually has converged for that many epochs
train_data = data
test_data = data 
nnet.gradient_descent(train_data, epochs, learning_rate, test_data)
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch 1: Accuracy 150 / 300 loss: [2.23779328e-18]
# Epoch 2: Accuracy 150 / 300 loss: [3.86724796e-16]
# Epoch 3: Accuracy 150 / 300 loss: [4.33449573e-17]
# Epoch 4: Accuracy 150 / 300 loss: [5.22961304e-17]
# Epoch 5: Accuracy 150 / 300 loss: [-2.31296463e-18]
# Epoch 6: Accuracy 150 / 300 loss: [1.30451205e-17]
# Epoch 7: Accuracy 150 / 300 loss: [-3.70074342e-18]
# Epoch 8: Accuracy 150 / 300 loss: [3.88578059e-18]
# Epoch 9: Accuracy 150 / 300 loss: [-5.18104078e-18]
# Epoch 10: Accuracy 150 / 300 loss: [1.64683082e-17]
# Epoch 11: Accuracy 150 / 300 loss: [-7.03141249e-18]
# Epoch 12: Accuracy 150 / 300 loss: [-3.33066907e-18]
# Epoch 13: Accuracy 150 / 300 loss: [-1.11022302e-18]
# Epoch 14: Accuracy 167 / 300 loss: [-7.77156117e-18]
# Epoch 15: Accuracy 150 / 300 loss: [4.07081776e-18]
# Epoch 16: Accuracy 203 / 300 loss: [-4.81096644e-18]
# Epoch 17: Accuracy 152 / 300 loss: [-1.88737914e-17]
# Epoch 18: Accuracy 195 / 300 loss: [1.14723046e-17]
# Epoch 19: Accuracy 158 / 300 loss: [7.77156117e-18]
# Epoch 20: Accuracy 185 / 300 loss: [-2.29446092e-17]
# Epoch 21: Accuracy 166 / 300 loss: [-7.40148683e-19]
# Epoch 22: Accuracy 184 / 300 loss: [9.99200722e-18]
# Epoch 23: Accuracy 166 / 300 loss: [2.22044605e-18]
# Epoch 24: Accuracy 180 / 300 loss: [-1.22124533e-17]
# Epoch 25: Accuracy 167 / 300 loss: [-6.29126381e-18]
# Epoch 26: Accuracy 178 / 300 loss: [-4.4408921e-18]
# Epoch 27: Accuracy 168 / 300 loss: [1.48029737e-18]
# Epoch 28: Accuracy 176 / 300 loss: [-2.96059473e-18]
# Epoch 29: Accuracy 169 / 300 loss: [1.18423789e-17]
# Epoch 30: Accuracy 176 / 300 loss: [-9.62193288e-18]
# Epoch 31: Accuracy 170 / 300 loss: [-9.25185854e-19]
# Epoch 32: Accuracy 176 / 300 loss: [7.03141249e-18]
# Epoch 33: Accuracy 167 / 300 loss: [-5.18104078e-18]
# Epoch 34: Accuracy 176 / 300 loss: [-3.1456319e-18]
# Epoch 35: Accuracy 168 / 300 loss: [1.66533454e-18]
# Epoch 36: Accuracy 175 / 300 loss: [-3.88578059e-18]
# Epoch 37: Accuracy 168 / 300 loss: [4.62592927e-18]
# Epoch 38: Accuracy 175 / 300 loss: [-5.36607795e-18]
# Epoch 39: Accuracy 166 / 300 loss: [-1.57281595e-17]
# Epoch 40: Accuracy 176 / 300 loss: [8.32667268e-18]
# Epoch 41: Accuracy 161 / 300 loss: [-7.586524e-18]
# Epoch 42: Accuracy 181 / 300 loss: [2.40548322e-18]
# Epoch 43: Accuracy 157 / 300 loss: [3.33066907e-18]
# Epoch 44: Accuracy 181 / 300 loss: [-3.70074342e-19]
# Epoch 45: Accuracy 155 / 300 loss: [7.03141249e-18]
# Epoch 46: Accuracy 189 / 300 loss: [6.84637532e-18]
# Epoch 47: Accuracy 167 / 300 loss: [-6.84637532e-18]
# Epoch 48: Accuracy 190 / 300 loss: [7.21644966e-18]
# Epoch 49: Accuracy 169 / 300 loss: [-8.8817842e-18]
# Epoch 50: Accuracy 159 / 300 loss: [6.10622664e-18]
# Epoch 51: Accuracy 150 / 300 loss: [-1.94289029e-18]
# Epoch 52: Accuracy 150 / 300 loss: [-1.01307851e-17]
# Epoch 53: Accuracy 150 / 300 loss: [1.07321559e-17]
# Epoch 54: Accuracy 150 / 300 loss: [5.92118946e-18]
# Epoch 55: Accuracy 150 / 300 loss: [-4.90348503e-18]
# Epoch 56: Accuracy 150 / 300 loss: [6.10622664e-18]
# Epoch 57: Accuracy 151 / 300 loss: [0.]
# Epoch 58: Accuracy 161 / 300 loss: [-4.99600361e-18]
# Epoch 59: Accuracy 172 / 300 loss: [4.07081776e-18]
# Epoch 60: Accuracy 187 / 300 loss: [-1.07321559e-17]
# Epoch 61: Accuracy 178 / 300 loss: [-1.85037171e-19]
# Epoch 62: Accuracy 191 / 300 loss: [9.25185854e-19]
# Epoch 63: Accuracy 167 / 300 loss: [4.62592927e-18]
# Epoch 64: Accuracy 190 / 300 loss: [-4.99600361e-18]
# Epoch 65: Accuracy 166 / 300 loss: [8.69674703e-18]
# Epoch 66: Accuracy 185 / 300 loss: [2.03540888e-18]
# Epoch 67: Accuracy 166 / 300 loss: [-3.1456319e-18]
# Epoch 68: Accuracy 185 / 300 loss: [-9.43689571e-18]
# Epoch 69: Accuracy 166 / 300 loss: [2.59052039e-18]
# Epoch 70: Accuracy 184 / 300 loss: [1.2952602e-18]
# Epoch 71: Accuracy 166 / 300 loss: [4.62592927e-18]
# Epoch 72: Accuracy 186 / 300 loss: [-2.40548322e-18]
# Epoch 73: Accuracy 165 / 300 loss: [-6.84637532e-18]
# Epoch 74: Accuracy 191 / 300 loss: [-1.75785312e-18]
# Epoch 75: Accuracy 172 / 300 loss: [2.77555756e-19]
# Epoch 76: Accuracy 190 / 300 loss: [6.01370805e-18]
# Epoch 77: Accuracy 181 / 300 loss: [-3.70074342e-18]
# Epoch 78: Accuracy 187 / 300 loss: [-2.49800181e-18]
# Epoch 79: Accuracy 179 / 300 loss: [2.96059473e-18]
# Epoch 80: Accuracy 180 / 300 loss: [-2.31296463e-18]
# Epoch 81: Accuracy 169 / 300 loss: [-5.55111512e-19]
# Epoch 82: Accuracy 169 / 300 loss: [1.11022302e-18]
# Epoch 83: Accuracy 165 / 300 loss: [-1.94289029e-18]
# Epoch 84: Accuracy 165 / 300 loss: [-3.793262e-18]
# Epoch 85: Accuracy 169 / 300 loss: [3.97829917e-18]
# Epoch 86: Accuracy 173 / 300 loss: [-6.56881956e-18]
# Epoch 87: Accuracy 171 / 300 loss: [4.99600361e-18]
# Epoch 88: Accuracy 184 / 300 loss: [-1.0269563e-17]
# Epoch 89: Accuracy 177 / 300 loss: [-5.55111512e-19]
# Epoch 90: Accuracy 185 / 300 loss: [-4.71844785e-18]
# Epoch 91: Accuracy 181 / 300 loss: [-3.33066907e-18]
# Epoch 92: Accuracy 191 / 300 loss: [-1.94289029e-18]
# Epoch 93: Accuracy 178 / 300 loss: [-3.97829917e-18]
# Epoch 94: Accuracy 191 / 300 loss: [7.40148683e-19]
# Epoch 95: Accuracy 170 / 300 loss: [-1.74860126e-17]
# Epoch 96: Accuracy 188 / 300 loss: [9.80697005e-18]
# Epoch 97: Accuracy 167 / 300 loss: [9.25185854e-20]
# Epoch 98: Accuracy 187 / 300 loss: [-3.23815049e-18]
# Epoch 99: Accuracy 167 / 300 loss: [5.0885222e-18]
# Epoch 100: Accuracy 186 / 300 loss: [-9.06682137e-18]
# Epoch 101: Accuracy 167 / 300 loss: [3.1456319e-18]
# Epoch 102: Accuracy 187 / 300 loss: [-1.20274161e-17]
# Epoch 103: Accuracy 169 / 300 loss: [8.97430278e-18]
# Epoch 104: Accuracy 189 / 300 loss: [8.32667268e-19]
# Epoch 105: Accuracy 170 / 300 loss: [-5.92118946e-18]
# Epoch 106: Accuracy 191 / 300 loss: [-2.03540888e-18]
# Epoch 107: Accuracy 177 / 300 loss: [-5.92118946e-18]
# Epoch 108: Accuracy 190 / 300 loss: [-7.86407976e-18]
# Epoch 109: Accuracy 178 / 300 loss: [1.57281595e-18]
# Epoch 110: Accuracy 192 / 300 loss: [-2.59052039e-18]
# Epoch 111: Accuracy 180 / 300 loss: [8.60422844e-18]
# Epoch 112: Accuracy 190 / 300 loss: [1.07321559e-17]
# Epoch 113: Accuracy 181 / 300 loss: [2.31296463e-18]
# Epoch 114: Accuracy 189 / 300 loss: [-8.41919127e-18]
# Epoch 115: Accuracy 180 / 300 loss: [4.62592927e-19]
# Epoch 116: Accuracy 189 / 300 loss: [-1.0269563e-17]
# Epoch 117: Accuracy 181 / 300 loss: [-9.34437712e-18]
# Epoch 118: Accuracy 189 / 300 loss: [-9.99200722e-18]
# Epoch 119: Accuracy 181 / 300 loss: [9.25185854e-19]
# Epoch 120: Accuracy 191 / 300 loss: [-1.53580852e-17]
# Epoch 121: Accuracy 178 / 300 loss: [-4.62592927e-18]
# Epoch 122: Accuracy 188 / 300 loss: [-1.48029737e-18]
# Epoch 123: Accuracy 179 / 300 loss: [1.55431223e-17]
# Epoch 124: Accuracy 190 / 300 loss: [-5.82867088e-18]
# Epoch 125: Accuracy 174 / 300 loss: [-1.94289029e-18]
# Epoch 126: Accuracy 190 / 300 loss: [-2.77555756e-18]
# Epoch 127: Accuracy 172 / 300 loss: [-5.27355937e-18]
# Epoch 128: Accuracy 190 / 300 loss: [-2.12792746e-18]
# Epoch 129: Accuracy 169 / 300 loss: [-9.15933995e-18]
# Epoch 130: Accuracy 186 / 300 loss: [6.19874522e-18]
# Epoch 131: Accuracy 168 / 300 loss: [5.55111512e-19]
# Epoch 132: Accuracy 183 / 300 loss: [-6.56881956e-18]
# Epoch 133: Accuracy 168 / 300 loss: [-2.40548322e-18]
# Epoch 134: Accuracy 183 / 300 loss: [1.01770444e-17]
# Epoch 135: Accuracy 168 / 300 loss: [-2.59052039e-18]
# Epoch 136: Accuracy 183 / 300 loss: [1.66533454e-18]
# Epoch 137: Accuracy 168 / 300 loss: [-2.15568304e-17]
# Epoch 138: Accuracy 183 / 300 loss: [9.43689571e-18]
# Epoch 139: Accuracy 168 / 300 loss: [-2.77555756e-18]
# Epoch 140: Accuracy 183 / 300 loss: [8.14163551e-18]
# Epoch 141: Accuracy 168 / 300 loss: [9.80697005e-18]
# Epoch 142: Accuracy 185 / 300 loss: [4.81096644e-18]
# Epoch 143: Accuracy 168 / 300 loss: [-1.11022302e-18]
# Epoch 144: Accuracy 186 / 300 loss: [-8.41919127e-18]
# Epoch 145: Accuracy 168 / 300 loss: [1.49880108e-17]
# Epoch 146: Accuracy 189 / 300 loss: [3.97829917e-18]
# Epoch 147: Accuracy 168 / 300 loss: [-6.9388939e-18]
# Epoch 148: Accuracy 190 / 300 loss: [9.62193288e-18]
# Epoch 149: Accuracy 169 / 300 loss: [-8.97430278e-18]
# Epoch 150: Accuracy 191 / 300 loss: [-4.71844785e-18]
# Epoch 151: Accuracy 169 / 300 loss: [6.19874522e-18]
# Epoch 152: Accuracy 191 / 300 loss: [-1.85037171e-18]
# Epoch 153: Accuracy 169 / 300 loss: [-3.33066907e-18]
# Epoch 198: Accuracy 185 / 300 loss: [7.03141249e-18]
# Epoch 199: Accuracy 169 / 300 loss: [-1.08246745e-17]
# Epoch 200: Accuracy 185 / 300 loss: [-9.43689571e-18]
# Epoch 201: Accuracy 169 / 300 loss: [1.00845258e-17]
# Epoch 202: Accuracy 185 / 300 loss: [-8.60422844e-18]
# Epoch 203: Accuracy 169 / 300 loss: [-4.07081776e-18]
# Epoch 204: Accuracy 185 / 300 loss: [9.99200722e-18]
# Epoch 205: Accuracy 169 / 300 loss: [3.05311332e-18]
# Epoch 206: Accuracy 184 / 300 loss: [-4.71844785e-18]
# Epoch 207: Accuracy 169 / 300 loss: [-2.12792746e-18]
# Epoch 208: Accuracy 186 / 300 loss: [-9.25185854e-18]
# Epoch 209: Accuracy 170 / 300 loss: [-6.66133815e-18]
# Epoch 210: Accuracy 186 / 300 loss: [8.14163551e-18]
# Epoch 211: Accuracy 170 / 300 loss: [-2.40548322e-18]
# Epoch 212: Accuracy 186 / 300 loss: [-1.20274161e-18]
# Epoch 213: Accuracy 170 / 300 loss: [2.34997207e-17]
# Epoch 214: Accuracy 185 / 300 loss: [-1.23974904e-17]
# Epoch 215: Accuracy 170 / 300 loss: [1.32301577e-17]
# Epoch 216: Accuracy 185 / 300 loss: [-1.01770444e-17]
# Epoch 217: Accuracy 169 / 300 loss: [3.1456319e-18]
# Epoch 218: Accuracy 184 / 300 loss: [-3.60822483e-18]
# Epoch 219: Accuracy 169 / 300 loss: [8.41919127e-18]
# Epoch 220: Accuracy 184 / 300 loss: [1.85037171e-19]
# Epoch 221: Accuracy 169 / 300 loss: [1.41553436e-17]
# Epoch 222: Accuracy 184 / 300 loss: [-1.85037171e-18]
# Epoch 223: Accuracy 168 / 300 loss: [9.43689571e-18]
# Epoch 224: Accuracy 184 / 300 loss: [1.20274161e-18]
# Epoch 225: Accuracy 168 / 300 loss: [1.08246745e-17]
# Epoch 226: Accuracy 184 / 300 loss: [-1.75785312e-17]
# Epoch 227: Accuracy 168 / 300 loss: [-1.18423789e-17]
# Epoch 228: Accuracy 184 / 300 loss: [1.99840144e-17]
# Epoch 229: Accuracy 169 / 300 loss: [8.32667268e-19]
# Epoch 230: Accuracy 185 / 300 loss: [-2.22044605e-18]
# Epoch 231: Accuracy 169 / 300 loss: [-2.77555756e-18]
# Epoch 232: Accuracy 185 / 300 loss: [-5.0885222e-18]
# Epoch 233: Accuracy 169 / 300 loss: [7.95659834e-18]
# Epoch 234: Accuracy 186 / 300 loss: [-5.55111512e-18]
# Epoch 235: Accuracy 169 / 300 loss: [9.25185854e-20]
# Epoch 236: Accuracy 186 / 300 loss: [-5.64363371e-18]
# Epoch 237: Accuracy 168 / 300 loss: [-3.42318766e-18]
# Epoch 238: Accuracy 186 / 300 loss: [9.25185854e-19]
# Epoch 239: Accuracy 168 / 300 loss: [7.77156117e-18]
# Epoch 240: Accuracy 186 / 300 loss: [-8.32667268e-19]
# Epoch 241: Accuracy 168 / 300 loss: [-1.85037171e-18]
# Epoch 242: Accuracy 186 / 300 loss: [9.99200722e-18]
# Epoch 287: Accuracy 168 / 300 loss: [-2.68303898e-18]
# Epoch 288: Accuracy 187 / 300 loss: [2.49800181e-18]
# Epoch 289: Accuracy 168 / 300 loss: [1.52655666e-17]
# Epoch 290: Accuracy 186 / 300 loss: [1.75785312e-18]
# Epoch 291: Accuracy 168 / 300 loss: [-8.51170986e-18]
# Epoch 292: Accuracy 186 / 300 loss: [1.66533454e-18]
# Epoch 293: Accuracy 168 / 300 loss: [-3.1456319e-18]
# Epoch 294: Accuracy 187 / 300 loss: [-1.52655666e-17]
# Epoch 295: Accuracy 168 / 300 loss: [-3.1456319e-18]
# Epoch 296: Accuracy 188 / 300 loss: [4.25585493e-18]
# Epoch 297: Accuracy 168 / 300 loss: [-9.80697005e-18]
# Epoch 298: Accuracy 188 / 300 loss: [-4.71844785e-18]
# Epoch 299: Accuracy 168 / 300 loss: [-6.10622664e-18]
# Epoch 300: Accuracy 189 / 300 loss: [-3.70074342e-19]
# Epoch 301: Accuracy 168 / 300 loss: [-9.25185854e-19]
# Epoch 302: Accuracy 189 / 300 loss: [2.49800181e-18]
# Epoch 303: Accuracy 168 / 300 loss: [6.43004168e-18]
# Epoch 304: Accuracy 190 / 300 loss: [3.60822483e-18]
# Epoch 305: Accuracy 168 / 300 loss: [4.62592927e-18]
# Epoch 306: Accuracy 191 / 300 loss: [-2.86807615e-18]
# Epoch 307: Accuracy 168 / 300 loss: [4.34837351e-18]
# Epoch 308: Accuracy 191 / 300 loss: [-6.84637532e-18]
# Epoch 309: Accuracy 168 / 300 loss: [-7.86407976e-19]
# Epoch 310: Accuracy 191 / 300 loss: [-1.43403807e-17]
# Epoch 311: Accuracy 168 / 300 loss: [-1.67921232e-17]
# Epoch 312: Accuracy 191 / 300 loss: [1.21199347e-17]
# Epoch 313: Accuracy 168 / 300 loss: [-1.07784152e-17]
# Epoch 314: Accuracy 191 / 300 loss: [-1.20274161e-17]
# Epoch 315: Accuracy 168 / 300 loss: [5.73615229e-18]
# Epoch 316: Accuracy 191 / 300 loss: [1.94289029e-18]
# Epoch 317: Accuracy 168 / 300 loss: [-8.8355249e-18]
# Epoch 318: Accuracy 191 / 300 loss: [8.60422844e-18]
# Epoch 319: Accuracy 168 / 300 loss: [2.45174251e-18]
# Epoch 320: Accuracy 192 / 300 loss: [2.77555756e-19]
# Epoch 321: Accuracy 168 / 300 loss: [-5.41233725e-18]
# Epoch 322: Accuracy 192 / 300 loss: [-1.01770444e-17]
# Epoch 323: Accuracy 168 / 300 loss: [1.31838984e-17]
# Epoch 324: Accuracy 191 / 300 loss: [-3.793262e-18]
# Epoch 325: Accuracy 168 / 300 loss: [-2.4656203e-17]
# Epoch 326: Accuracy 191 / 300 loss: [4.81096644e-18]
# Epoch 327: Accuracy 168 / 300 loss: [-8.74300632e-18]
# Epoch 328: Accuracy 191 / 300 loss: [1.54506038e-17]
# Epoch 329: Accuracy 169 / 300 loss: [6.01370805e-18]
# Epoch 330: Accuracy 193 / 300 loss: [-9.62193288e-18]
# Epoch 331: Accuracy 169 / 300 loss: [1.52193073e-17]
# Epoch 332: Accuracy 193 / 300 loss: [4.4408921e-18]
# Epoch 333: Accuracy 169 / 300 loss: [-3.33066907e-18]
# Epoch 334: Accuracy 193 / 300 loss: [-1.00845258e-17]
# Epoch 335: Accuracy 169 / 300 loss: [-1.00382665e-17]
# Epoch 336: Accuracy 193 / 300 loss: [1.23974904e-17]
# Epoch 337: Accuracy 169 / 300 loss: [-5.41233725e-18]
# Epoch 338: Accuracy 193 / 300 loss: [5.55111512e-18]
# Epoch 339: Accuracy 169 / 300 loss: [-2.31296463e-19]
# Epoch 340: Accuracy 193 / 300 loss: [1.58206781e-17]
# Epoch 341: Accuracy 170 / 300 loss: [-1.00382665e-17]
# Epoch 342: Accuracy 193 / 300 loss: [5.73615229e-18]
# Epoch 343: Accuracy 170 / 300 loss: [6.38378239e-18]
# Epoch 344: Accuracy 193 / 300 loss: [-5.27355937e-18]
# Epoch 345: Accuracy 170 / 300 loss: [4.62592927e-19]
# Epoch 346: Accuracy 193 / 300 loss: [-5.45859654e-18]
# Epoch 347: Accuracy 171 / 300 loss: [1.15185639e-17]
# Epoch 348: Accuracy 193 / 300 loss: [6.38378239e-18]
# Epoch 349: Accuracy 171 / 300 loss: [1.5173048e-17]
# Epoch 350: Accuracy 193 / 300 loss: [-2.21119419e-17]
# Epoch 351: Accuracy 172 / 300 loss: [-6.05996734e-18]
# Epoch 352: Accuracy 193 / 300 loss: [6.29126381e-18]
# Epoch 353: Accuracy 172 / 300 loss: [-1.57281595e-18]
# Epoch 354: Accuracy 194 / 300 loss: [5.45859654e-18]
# Epoch 355: Accuracy 171 / 300 loss: [-6.01370805e-18]
# Epoch 356: Accuracy 194 / 300 loss: [-1.02233037e-17]
# Epoch 357: Accuracy 171 / 300 loss: [-9.06682137e-18]
# Epoch 358: Accuracy 195 / 300 loss: [2.0076533e-17]
# Epoch 359: Accuracy 171 / 300 loss: [-1.66533454e-18]
# Epoch 360: Accuracy 195 / 300 loss: [-6.38378239e-18]
# Epoch 361: Accuracy 171 / 300 loss: [1.21199347e-17]
# Epoch 362: Accuracy 195 / 300 loss: [6.56881956e-18]
# Epoch 363: Accuracy 172 / 300 loss: [3.86265094e-18]
# Epoch 364: Accuracy 196 / 300 loss: [4.53341068e-18]
# Epoch 365: Accuracy 173 / 300 loss: [-4.48715139e-18]
# Epoch 366: Accuracy 196 / 300 loss: [5.45859654e-18]
# Epoch 367: Accuracy 173 / 300 loss: [-4.62592927e-19]
# Epoch 368: Accuracy 196 / 300 loss: [1.93826436e-17]
# Epoch 369: Accuracy 173 / 300 loss: [3.77013235e-18]
# Epoch 370: Accuracy 196 / 300 loss: [-1.85037171e-19]
# Epoch 371: Accuracy 173 / 300 loss: [-8.55796915e-18]
# Epoch 372: Accuracy 197 / 300 loss: [-1.19811568e-17]
# Epoch 373: Accuracy 173 / 300 loss: [-1.87350135e-18]
# Epoch 374: Accuracy 197 / 300 loss: [1.97064587e-17]
# Epoch 375: Accuracy 173 / 300 loss: [7.86407976e-19]
# Epoch 376: Accuracy 198 / 300 loss: [8.78926561e-19]
# Epoch 377: Accuracy 173 / 300 loss: [1.98914959e-18]
# Epoch 378: Accuracy 198 / 300 loss: [-1.00845258e-17]
# Epoch 379: Accuracy 172 / 300 loss: [-5.36607795e-18]
# Epoch 380: Accuracy 198 / 300 loss: [2.22044605e-18]
# Epoch 381: Accuracy 172 / 300 loss: [1.26287869e-17]
# Epoch 382: Accuracy 198 / 300 loss: [2.08166817e-18]
# Epoch 383: Accuracy 172 / 300 loss: [1.66533454e-17]
# Epoch 384: Accuracy 197 / 300 loss: [-1.88275321e-17]
# Epoch 385: Accuracy 172 / 300 loss: [-3.70074342e-18]
# Epoch 386: Accuracy 198 / 300 loss: [7.21644966e-18]
# Epoch 387: Accuracy 172 / 300 loss: [-5.15791114e-18]
# Epoch 388: Accuracy 198 / 300 loss: [-1.51267887e-17]
# Epoch 389: Accuracy 172 / 300 loss: [-2.68303898e-18]
# Epoch 390: Accuracy 198 / 300 loss: [1.20274161e-18]
# Epoch 391: Accuracy 172 / 300 loss: [-1.03852112e-17]
# Epoch 392: Accuracy 198 / 300 loss: [-5.55111512e-19]
# Epoch 393: Accuracy 172 / 300 loss: [-1.61907524e-19]
# Epoch 394: Accuracy 198 / 300 loss: [-4.57966998e-18]
# Epoch 395: Accuracy 171 / 300 loss: [-4.11707705e-18]
# Epoch 396: Accuracy 198 / 300 loss: [7.21644966e-18]
# Epoch 397: Accuracy 172 / 300 loss: [-4.4408921e-18]
# Epoch 398: Accuracy 198 / 300 loss: [6.84637532e-18]
# Epoch 399: Accuracy 172 / 300 loss: [-4.39463281e-19]
# Epoch 400: Accuracy 198 / 300 loss: [2.68303898e-18]
# Epoch 401: Accuracy 172 / 300 loss: [7.19332001e-18]
# Epoch 402: Accuracy 199 / 300 loss: [5.18104078e-18]
# Epoch 403: Accuracy 172 / 300 loss: [-1.31838984e-17]
# Epoch 404: Accuracy 200 / 300 loss: [-1.04083409e-17]
# Epoch 405: Accuracy 173 / 300 loss: [9.11308066e-18]
# Epoch 406: Accuracy 200 / 300 loss: [-2.86807615e-18]
# Epoch 407: Accuracy 173 / 300 loss: [-2.79868721e-18]
# Epoch 408: Accuracy 200 / 300 loss: [1.29988612e-17]
# Epoch 409: Accuracy 173 / 300 loss: [3.07624296e-18]
# Epoch 410: Accuracy 200 / 300 loss: [2.99297624e-17]
# Epoch 411: Accuracy 173 / 300 loss: [9.50628465e-18]
# Epoch 412: Accuracy 200 / 300 loss: [-1.52655666e-18]
# Epoch 413: Accuracy 173 / 300 loss: [-4.1402067e-18]
# Epoch 414: Accuracy 201 / 300 loss: [-1.65608268e-17]
# Epoch 415: Accuracy 173 / 300 loss: [-2.10479782e-18]
# Epoch 416: Accuracy 201 / 300 loss: [8.14163551e-18]
# Epoch 417: Accuracy 173 / 300 loss: [1.06396373e-18]
# Epoch 418: Accuracy 201 / 300 loss: [1.17961196e-17]
# Epoch 419: Accuracy 171 / 300 loss: [-1.54968631e-18]
# Epoch 420: Accuracy 201 / 300 loss: [-2.96059473e-18]
# Epoch 421: Accuracy 170 / 300 loss: [-4.57966998e-18]
# Epoch 422: Accuracy 201 / 300 loss: [1.48029737e-18]
# Epoch 423: Accuracy 170 / 300 loss: [-8.25728375e-18]
# Epoch 424: Accuracy 201 / 300 loss: [-3.93203988e-18]
# Epoch 425: Accuracy 169 / 300 loss: [-1.08940634e-17]
# Epoch 426: Accuracy 201 / 300 loss: [1.99840144e-17]
# Epoch 427: Accuracy 168 / 300 loss: [3.46944695e-18]
# Epoch 428: Accuracy 201 / 300 loss: [1.48029737e-18]
# Epoch 429: Accuracy 168 / 300 loss: [8.48858021e-18]
# Epoch 430: Accuracy 201 / 300 loss: [7.03141249e-18]
# Epoch 431: Accuracy 168 / 300 loss: [6.9851532e-18]
# Epoch 432: Accuracy 201 / 300 loss: [-1.23974904e-17]
# Epoch 433: Accuracy 168 / 300 loss: [-4.4408921e-18]
# Epoch 434: Accuracy 202 / 300 loss: [-1.05008594e-17]
# Epoch 435: Accuracy 167 / 300 loss: [-9.22872889e-18]
# Epoch 436: Accuracy 202 / 300 loss: [2.72929827e-18]
# Epoch 437: Accuracy 166 / 300 loss: [4.85722573e-19]
# Epoch 438: Accuracy 202 / 300 loss: [-4.16333634e-19]
# Epoch 439: Accuracy 166 / 300 loss: [-1.22587126e-17]
# Epoch 440: Accuracy 202 / 300 loss: [1.12872674e-17]
# Epoch 441: Accuracy 166 / 300 loss: [-5.11165184e-18]
# Epoch 442: Accuracy 202 / 300 loss: [-5.31981866e-18]
# Epoch 443: Accuracy 167 / 300 loss: [2.77555756e-19]
# Epoch 444: Accuracy 203 / 300 loss: [-1.97989773e-17]
# Epoch 445: Accuracy 167 / 300 loss: [-3.58509518e-18]
# Epoch 446: Accuracy 203 / 300 loss: [-1.17961196e-17]
# Epoch 447: Accuracy 168 / 300 loss: [-2.17418676e-18]
# Epoch 448: Accuracy 203 / 300 loss: [7.95659834e-18]
# Epoch 449: Accuracy 169 / 300 loss: [-6.02527287e-18]
# Epoch 450: Accuracy 205 / 300 loss: [2.77555756e-18]
# Epoch 451: Accuracy 170 / 300 loss: [2.98372438e-18]
# Epoch 452: Accuracy 205 / 300 loss: [-6.9388939e-19]
# Epoch 453: Accuracy 171 / 300 loss: [-1.08709338e-18]
# Epoch 454: Accuracy 207 / 300 loss: [7.17019037e-18]
# Epoch 455: Accuracy 172 / 300 loss: [-4.23272528e-18]
# Epoch 456: Accuracy 207 / 300 loss: [7.40148683e-18]
# Epoch 457: Accuracy 172 / 300 loss: [9.679757e-18]
# Epoch 458: Accuracy 208 / 300 loss: [1.06396373e-18]
# Epoch 459: Accuracy 172 / 300 loss: [6.73072709e-18]
# Epoch 460: Accuracy 207 / 300 loss: [2.77555756e-19]
# Epoch 461: Accuracy 172 / 300 loss: [-3.73543788e-18]
# Epoch 462: Accuracy 206 / 300 loss: [9.99200722e-18]
# Epoch 463: Accuracy 173 / 300 loss: [1.17961196e-18]
# Epoch 464: Accuracy 205 / 300 loss: [-6.70759744e-19]
# Epoch 465: Accuracy 174 / 300 loss: [5.51642065e-18]
# Epoch 466: Accuracy 207 / 300 loss: [-1.38083989e-17]
# Epoch 467: Accuracy 181 / 300 loss: [6.88106979e-18]
# Epoch 468: Accuracy 208 / 300 loss: [1.2490009e-18]
# Epoch 469: Accuracy 183 / 300 loss: [-1.53349555e-17]
# Epoch 470: Accuracy 211 / 300 loss: [-8.07224657e-18]
# Epoch 471: Accuracy 183 / 300 loss: [1.14723046e-17]
# Epoch 472: Accuracy 212 / 300 loss: [4.85722573e-19]
# Epoch 473: Accuracy 185 / 300 loss: [6.12935628e-19]
# Epoch 474: Accuracy 213 / 300 loss: [-7.63278329e-18]
# Epoch 475: Accuracy 184 / 300 loss: [-8.75457114e-18]
# Epoch 476: Accuracy 216 / 300 loss: [-9.25185854e-20]
# Epoch 477: Accuracy 185 / 300 loss: [5.52798548e-18]
# Epoch 478: Accuracy 218 / 300 loss: [1.61907524e-19]
# Epoch 479: Accuracy 187 / 300 loss: [2.07010335e-18]
# Epoch 480: Accuracy 218 / 300 loss: [3.23815049e-19]
# Epoch 481: Accuracy 190 / 300 loss: [1.25247035e-17]
# Epoch 482: Accuracy 219 / 300 loss: [-6.47630098e-19]
# Epoch 483: Accuracy 191 / 300 loss: [-1.11022302e-18]
# Epoch 484: Accuracy 221 / 300 loss: [4.55654033e-18]
# Epoch 485: Accuracy 193 / 300 loss: [-6.01370805e-18]
# Epoch 486: Accuracy 222 / 300 loss: [6.47630098e-19]
# Epoch 487: Accuracy 195 / 300 loss: [-6.51099545e-18]
# Epoch 488: Accuracy 223 / 300 loss: [-5.43546689e-18]
# Epoch 489: Accuracy 197 / 300 loss: [1.95445512e-18]
# Epoch 490: Accuracy 223 / 300 loss: [-9.36750677e-18]
# Epoch 491: Accuracy 199 / 300 loss: [-1.31492039e-17]
# Epoch 492: Accuracy 223 / 300 loss: [-8.78926561e-19]
# Epoch 493: Accuracy 204 / 300 loss: [-3.26128013e-18]
# Epoch 494: Accuracy 223 / 300 loss: [4.25585493e-18]
# Epoch 495: Accuracy 206 / 300 loss: [-7.89877423e-18]
# Epoch 496: Accuracy 224 / 300 loss: [1.45485476e-17]
# Epoch 497: Accuracy 208 / 300 loss: [-2.72929827e-18]
# Epoch 498: Accuracy 225 / 300 loss: [1.25825276e-17]
# Epoch 499: Accuracy 209 / 300 loss: [-4.16333634e-19]
# Epoch 500: Accuracy 227 / 300 loss: [1.46179365e-17]
# Epoch 501: Accuracy 211 / 300 loss: [1.0466165e-17]
# Epoch 502: Accuracy 227 / 300 loss: [-7.51713506e-18]
# Epoch 503: Accuracy 212 / 300 loss: [1.15648232e-20]
# Epoch 504: Accuracy 227 / 300 loss: [-9.1824696e-18]
# Epoch 505: Accuracy 213 / 300 loss: [7.51713506e-19]
# Epoch 506: Accuracy 225 / 300 loss: [-7.07767178e-18]
# Epoch 507: Accuracy 218 / 300 loss: [-5.37764278e-18]
# Epoch 508: Accuracy 225 / 300 loss: [-3.53883589e-18]
# Epoch 509: Accuracy 218 / 300 loss: [-8.44232092e-19]
# Epoch 510: Accuracy 225 / 300 loss: [-2.93746509e-18]
# Epoch 511: Accuracy 218 / 300 loss: [1.78098277e-18]
# Epoch 512: Accuracy 226 / 300 loss: [-9.36750677e-18]
# Epoch 513: Accuracy 216 / 300 loss: [-1.50342701e-18]
# Epoch 514: Accuracy 226 / 300 loss: [-3.60822483e-18]
# Epoch 515: Accuracy 216 / 300 loss: [1.85037171e-19]
# Epoch 516: Accuracy 228 / 300 loss: [-1.78098277e-18]
# Epoch 517: Accuracy 214 / 300 loss: [-1.6283271e-17]
# Epoch 518: Accuracy 229 / 300 loss: [3.81639165e-18]
# Epoch 519: Accuracy 215 / 300 loss: [-4.62592927e-20]
# Epoch 520: Accuracy 229 / 300 loss: [-2.08166817e-19]
# Epoch 521: Accuracy 215 / 300 loss: [8.29197822e-18]
# Epoch 522: Accuracy 229 / 300 loss: [-1.4259427e-17]
# Epoch 523: Accuracy 216 / 300 loss: [1.91860416e-17]
# Epoch 524: Accuracy 229 / 300 loss: [7.64434812e-18]
# Epoch 525: Accuracy 217 / 300 loss: [7.66747776e-18]
# Epoch 526: Accuracy 228 / 300 loss: [-3.00685403e-19]
# Epoch 527: Accuracy 217 / 300 loss: [7.57495918e-18]
# Epoch 528: Accuracy 229 / 300 loss: [-1.43403807e-18]
# Epoch 529: Accuracy 217 / 300 loss: [-5.42390207e-18]
# Epoch 530: Accuracy 229 / 300 loss: [1.75785312e-18]
# Epoch 531: Accuracy 217 / 300 loss: [-1.31954632e-17]
# Epoch 532: Accuracy 228 / 300 loss: [7.75999635e-18]
# Epoch 533: Accuracy 217 / 300 loss: [9.20559925e-18]
# Epoch 534: Accuracy 226 / 300 loss: [-1.70928086e-17]
# Epoch 535: Accuracy 217 / 300 loss: [2.20888123e-18]
# Epoch 536: Accuracy 226 / 300 loss: [1.12410081e-17]
# Epoch 537: Accuracy 217 / 300 loss: [-9.59880323e-18]
# Epoch 538: Accuracy 227 / 300 loss: [3.75856753e-18]
# Epoch 539: Accuracy 218 / 300 loss: [8.67361738e-20]
# Epoch 540: Accuracy 227 / 300 loss: [-5.62050406e-18]
# Epoch 541: Accuracy 219 / 300 loss: [5.11743425e-18]
# Epoch 542: Accuracy 227 / 300 loss: [1.09981468e-17]
# Epoch 543: Accuracy 220 / 300 loss: [6.89263461e-18]
# Epoch 544: Accuracy 227 / 300 loss: [4.20959564e-18]
# Epoch 545: Accuracy 220 / 300 loss: [-1.89084859e-18]
# Epoch 546: Accuracy 227 / 300 loss: [-5.30825384e-18]
# Epoch 547: Accuracy 220 / 300 loss: [5.41811966e-18]
# Epoch 548: Accuracy 227 / 300 loss: [1.63064007e-18]
# Epoch 549: Accuracy 221 / 300 loss: [-8.98586761e-18]
# Epoch 550: Accuracy 227 / 300 loss: [9.69132182e-18]
# Epoch 551: Accuracy 222 / 300 loss: [-5.07695737e-18]
# Epoch 552: Accuracy 227 / 300 loss: [-2.82181685e-18]
# Epoch 553: Accuracy 224 / 300 loss: [2.15683952e-18]
# Epoch 554: Accuracy 227 / 300 loss: [-4.15177152e-18]
# Epoch 555: Accuracy 224 / 300 loss: [-4.92661467e-18]
# Epoch 556: Accuracy 227 / 300 loss: [-6.91576426e-18]
# Epoch 557: Accuracy 225 / 300 loss: [1.57455068e-17]
# Epoch 558: Accuracy 226 / 300 loss: [8.0838114e-18]
# Epoch 559: Accuracy 225 / 300 loss: [-6.15248593e-18]
# Epoch 560: Accuracy 226 / 300 loss: [8.14163551e-18]
# Epoch 561: Accuracy 225 / 300 loss: [7.14706072e-18]
# Epoch 562: Accuracy 227 / 300 loss: [-2.89120579e-18]
# Epoch 563: Accuracy 225 / 300 loss: [-4.51028104e-19]
# Epoch 564: Accuracy 228 / 300 loss: [-7.14706072e-18]
# Epoch 565: Accuracy 225 / 300 loss: [6.82324567e-19]
# Epoch 566: Accuracy 227 / 300 loss: [9.51784947e-18]
# Epoch 567: Accuracy 224 / 300 loss: [3.7412203e-18]
# Epoch 568: Accuracy 228 / 300 loss: [3.46944695e-20]
# Epoch 569: Accuracy 224 / 300 loss: [-1.32417225e-17]
# Epoch 570: Accuracy 228 / 300 loss: [1.71043735e-17]
# Epoch 571: Accuracy 224 / 300 loss: [4.1402067e-18]
# Epoch 572: Accuracy 228 / 300 loss: [3.21502084e-18]
# Epoch 573: Accuracy 223 / 300 loss: [9.77227558e-18]
# Epoch 574: Accuracy 229 / 300 loss: [-5.66676335e-18]
# Epoch 575: Accuracy 224 / 300 loss: [1.25189211e-17]
# Epoch 576: Accuracy 229 / 300 loss: [-1.31954632e-17]
# Epoch 577: Accuracy 224 / 300 loss: [-7.74843153e-18]
# Epoch 578: Accuracy 228 / 300 loss: [-1.43982049e-17]
# Epoch 579: Accuracy 224 / 300 loss: [-4.1402067e-18]
# Epoch 580: Accuracy 228 / 300 loss: [-1.50920942e-18]
# Epoch 581: Accuracy 226 / 300 loss: [-5.97901358e-18]
# Epoch 582: Accuracy 229 / 300 loss: [1.15648232e-18]
# Epoch 583: Accuracy 226 / 300 loss: [-1.31492039e-17]
# Epoch 584: Accuracy 230 / 300 loss: [1.28369537e-18]
# Epoch 585: Accuracy 225 / 300 loss: [-6.85215773e-18]
# Epoch 586: Accuracy 230 / 300 loss: [4.7415775e-19]
# Epoch 587: Accuracy 224 / 300 loss: [6.93311149e-18]
# Epoch 588: Accuracy 230 / 300 loss: [-2.49800181e-18]
# Epoch 589: Accuracy 224 / 300 loss: [6.42425927e-18]
# Epoch 590: Accuracy 230 / 300 loss: [4.33680869e-19]
# Epoch 591: Accuracy 224 / 300 loss: [5.90384223e-18]
# Epoch 592: Accuracy 231 / 300 loss: [-2.3476591e-18]
# Epoch 593: Accuracy 224 / 300 loss: [-1.30682502e-18]
# Epoch 594: Accuracy 231 / 300 loss: [2.48643698e-19]
# Epoch 595: Accuracy 224 / 300 loss: [4.48715139e-18]
# Epoch 596: Accuracy 231 / 300 loss: [-1.06974614e-17]
# Epoch 597: Accuracy 225 / 300 loss: [4.16333634e-18]
# Epoch 598: Accuracy 231 / 300 loss: [1.01365675e-17]
# Epoch 599: Accuracy 225 / 300 loss: [-3.87421576e-19]
# Epoch 600: Accuracy 231 / 300 loss: [-4.68375339e-18]
# Epoch 601: Accuracy 225 / 300 loss: [-5.46437895e-18]
# Epoch 602: Accuracy 230 / 300 loss: [9.7838404e-18]
# Epoch 603: Accuracy 225 / 300 loss: [1.06107253e-17]
# Epoch 604: Accuracy 230 / 300 loss: [-7.90455664e-18]
# Epoch 605: Accuracy 227 / 300 loss: [-2.1973164e-19]
# Epoch 606: Accuracy 230 / 300 loss: [-1.88622266e-17]
# Epoch 607: Accuracy 227 / 300 loss: [6.54279871e-18]
# Epoch 608: Accuracy 230 / 300 loss: [-1.11947488e-17]
# Epoch 609: Accuracy 227 / 300 loss: [-4.79940162e-18]
# Epoch 610: Accuracy 230 / 300 loss: [-2.55582592e-18]
# Epoch 611: Accuracy 227 / 300 loss: [3.18032637e-20]
# Epoch 612: Accuracy 229 / 300 loss: [-1.12410081e-17]
# Epoch 613: Accuracy 227 / 300 loss: [-5.79397641e-18]
# Epoch 614: Accuracy 229 / 300 loss: [-9.65084494e-18]
# Epoch 615: Accuracy 227 / 300 loss: [-3.37114595e-18]
# Epoch 616: Accuracy 229 / 300 loss: [3.20923843e-18]
# Epoch 617: Accuracy 227 / 300 loss: [6.06864096e-18]
# Epoch 618: Accuracy 230 / 300 loss: [-1.03042574e-17]
# Epoch 619: Accuracy 226 / 300 loss: [-7.6356745e-18]
# Epoch 620: Accuracy 230 / 300 loss: [1.0578922e-17]
# Epoch 621: Accuracy 226 / 300 loss: [-9.22872889e-18]
# Epoch 622: Accuracy 230 / 300 loss: [1.26056573e-18]
# Epoch 623: Accuracy 227 / 300 loss: [1.45716772e-18]
# Epoch 624: Accuracy 230 / 300 loss: [-6.16405075e-18]
# Epoch 625: Accuracy 227 / 300 loss: [-5.21284405e-18]
# Epoch 626: Accuracy 230 / 300 loss: [-4.4437833e-18]
# Epoch 627: Accuracy 227 / 300 loss: [6.74807432e-18]
# Epoch 628: Accuracy 230 / 300 loss: [-1.54390389e-18]
# Epoch 629: Accuracy 227 / 300 loss: [8.19945963e-18]
# Epoch 630: Accuracy 230 / 300 loss: [2.24039537e-17]
# Epoch 631: Accuracy 227 / 300 loss: [1.16544506e-17]
# Epoch 632: Accuracy 230 / 300 loss: [-1.21777588e-17]
# Epoch 633: Accuracy 227 / 300 loss: [-4.01877605e-18]
# Epoch 634: Accuracy 230 / 300 loss: [1.34498894e-17]
# Epoch 635: Accuracy 227 / 300 loss: [-5.91540705e-18]
# Epoch 636: Accuracy 230 / 300 loss: [-1.74050589e-18]
# Epoch 637: Accuracy 227 / 300 loss: [1.2559398e-17]
# Epoch 638: Accuracy 230 / 300 loss: [-3.44631731e-18]
# Epoch 639: Accuracy 227 / 300 loss: [-4.90926744e-18]
# Epoch 640: Accuracy 230 / 300 loss: [4.52762827e-18]
# Epoch 641: Accuracy 227 / 300 loss: [-4.54786671e-18]
# Epoch 642: Accuracy 230 / 300 loss: [1.20158513e-17]
# Epoch 643: Accuracy 228 / 300 loss: [1.71188295e-17]
# Epoch 644: Accuracy 230 / 300 loss: [-1.03591904e-17]
# Epoch 645: Accuracy 228 / 300 loss: [3.59955121e-18]
# Epoch 646: Accuracy 230 / 300 loss: [3.97540797e-18]
# Epoch 647: Accuracy 228 / 300 loss: [1.26692638e-17]
# Epoch 648: Accuracy 230 / 300 loss: [4.47558657e-18]
# Epoch 649: Accuracy 228 / 300 loss: [1.13393091e-17]
# Epoch 650: Accuracy 230 / 300 loss: [6.99960923e-18]
# Epoch 651: Accuracy 228 / 300 loss: [-7.43039889e-19]
# Epoch 652: Accuracy 230 / 300 loss: [-8.44232092e-19]
# Epoch 653: Accuracy 228 / 300 loss: [-8.10115863e-18]
# Epoch 654: Accuracy 230 / 300 loss: [-2.90566182e-18]
# Epoch 655: Accuracy 228 / 300 loss: [1.85788884e-17]
# Epoch 656: Accuracy 230 / 300 loss: [-1.4288339e-17]
# Epoch 657: Accuracy 228 / 300 loss: [1.03071487e-17]
# Epoch 658: Accuracy 230 / 300 loss: [6.80878964e-18]
# Epoch 659: Accuracy 228 / 300 loss: [-3.61689845e-18]
# Epoch 660: Accuracy 230 / 300 loss: [-3.3942756e-18]
# Epoch 661: Accuracy 228 / 300 loss: [5.60315683e-18]
# Epoch 662: Accuracy 230 / 300 loss: [1.00671786e-17]
# Epoch 663: Accuracy 228 / 300 loss: [1.81567724e-18]
# Epoch 664: Accuracy 230 / 300 loss: [3.67183136e-18]
# Epoch 665: Accuracy 228 / 300 loss: [1.11658368e-17]
# Epoch 666: Accuracy 230 / 300 loss: [9.34148592e-18]
# Epoch 667: Accuracy 228 / 300 loss: [-1.26432429e-17]
# Epoch 668: Accuracy 230 / 300 loss: [2.12330153e-17]
# Epoch 669: Accuracy 228 / 300 loss: [-1.00209193e-17]
# Epoch 670: Accuracy 230 / 300 loss: [-5.27645057e-18]
# Epoch 671: Accuracy 229 / 300 loss: [-2.10768902e-18]
# Epoch 672: Accuracy 230 / 300 loss: [-1.98047597e-18]
# Epoch 673: Accuracy 229 / 300 loss: [4.61147324e-18]
# Epoch 674: Accuracy 230 / 300 loss: [1.62774886e-18]
# Epoch 675: Accuracy 230 / 300 loss: [-1.79254759e-18]
# Epoch 676: Accuracy 230 / 300 loss: [-1.96601994e-19]
# Epoch 677: Accuracy 230 / 300 loss: [-3.26128013e-18]
# Epoch 678: Accuracy 230 / 300 loss: [-5.79686762e-18]
# Epoch 679: Accuracy 230 / 300 loss: [-6.49943062e-18]
# Epoch 680: Accuracy 230 / 300 loss: [4.01588485e-18]
# Epoch 681: Accuracy 230 / 300 loss: [-3.06467814e-19]
# Epoch 682: Accuracy 230 / 300 loss: [-5.43546689e-18]
# Epoch 683: Accuracy 230 / 300 loss: [8.44521212e-18]
# Epoch 684: Accuracy 230 / 300 loss: [2.78133997e-18]
# Epoch 685: Accuracy 230 / 300 loss: [1.56269673e-18]
# Epoch 686: Accuracy 230 / 300 loss: [-5.43691249e-18]
# Epoch 687: Accuracy 230 / 300 loss: [2.87385856e-18]
# Epoch 688: Accuracy 230 / 300 loss: [7.79902763e-18]
# Epoch 689: Accuracy 230 / 300 loss: [-6.52689708e-18]
# Epoch 690: Accuracy 230 / 300 loss: [-2.76977515e-18]
# Epoch 691: Accuracy 230 / 300 loss: [1.59955961e-17]
# Epoch 692: Accuracy 230 / 300 loss: [1.09779084e-17]
# Epoch 693: Accuracy 230 / 300 loss: [-8.12573388e-18]
# Epoch 694: Accuracy 230 / 300 loss: [1.13219619e-17]
# Epoch 695: Accuracy 230 / 300 loss: [5.33138348e-18]
# Epoch 696: Accuracy 230 / 300 loss: [-2.73218947e-18]
# Epoch 697: Accuracy 230 / 300 loss: [-2.31484392e-17]
# Epoch 698: Accuracy 230 / 300 loss: [-4.53341068e-18]
# Epoch 699: Accuracy 230 / 300 loss: [6.30282863e-18]
# Epoch 700: Accuracy 230 / 300 loss: [-1.86049093e-18]
# Epoch 701: Accuracy 230 / 300 loss: [3.40005801e-18]
# Epoch 702: Accuracy 230 / 300 loss: [1.27747928e-17]
# Epoch 703: Accuracy 230 / 300 loss: [-2.57750996e-18]
# Epoch 704: Accuracy 230 / 300 loss: [-1.78965639e-18]
# Epoch 705: Accuracy 230 / 300 loss: [-4.80229282e-18]
# Epoch 706: Accuracy 230 / 300 loss: [9.59880323e-18]
# Epoch 707: Accuracy 230 / 300 loss: [-6.18284359e-18]
# Epoch 708: Accuracy 230 / 300 loss: [1.05268803e-17]
# Epoch 709: Accuracy 230 / 300 loss: [-1.1492543e-17]
# Epoch 710: Accuracy 230 / 300 loss: [-9.0812774e-18]
# Epoch 711: Accuracy 230 / 300 loss: [-5.35451313e-18]
# Epoch 712: Accuracy 230 / 300 loss: [-5.78241159e-21]
# Epoch 713: Accuracy 230 / 300 loss: [-5.47160696e-18]
# Epoch 714: Accuracy 230 / 300 loss: [-7.5850784e-18]
# Epoch 715: Accuracy 230 / 300 loss: [7.61832727e-18]
# Epoch 716: Accuracy 230 / 300 loss: [-6.10044422e-18]
# Epoch 717: Accuracy 230 / 300 loss: [-1.57570716e-18]
# Epoch 718: Accuracy 230 / 300 loss: [9.71156026e-18]
# Epoch 719: Accuracy 230 / 300 loss: [3.29886581e-18]
# Epoch 720: Accuracy 230 / 300 loss: [6.67868538e-19]
# Epoch 721: Accuracy 230 / 300 loss: [-1.11022302e-17]
# Epoch 722: Accuracy 230 / 300 loss: [8.06646416e-18]
# Epoch 723: Accuracy 230 / 300 loss: [-9.30968265e-19]
# Epoch 724: Accuracy 230 / 300 loss: [-1.18944206e-17]
# Epoch 725: Accuracy 230 / 300 loss: [1.42825566e-18]
# Epoch 726: Accuracy 230 / 300 loss: [5.07117496e-18]
# Epoch 727: Accuracy 230 / 300 loss: [3.9927552e-18]
# Epoch 728: Accuracy 230 / 300 loss: [-1.15359111e-17]
# Epoch 729: Accuracy 230 / 300 loss: [6.91720986e-18]
# Epoch 730: Accuracy 230 / 300 loss: [-4.42065366e-18]
# Epoch 731: Accuracy 230 / 300 loss: [-1.07119175e-18]
# Epoch 732: Accuracy 230 / 300 loss: [3.95516953e-18]
# Epoch 733: Accuracy 230 / 300 loss: [1.1063199e-17]
# Epoch 734: Accuracy 230 / 300 loss: [9.84455573e-19]
# Epoch 735: Accuracy 230 / 300 loss: [-7.36100995e-18]
# Epoch 736: Accuracy 230 / 300 loss: [-6.03105528e-18]
# Epoch 737: Accuracy 230 / 300 loss: [1.6192198e-17]
# Epoch 738: Accuracy 230 / 300 loss: [9.80407885e-18]
# Epoch 739: Accuracy 230 / 300 loss: [3.66315774e-18]
# Epoch 740: Accuracy 230 / 300 loss: [7.586524e-18]
# Epoch 741: Accuracy 230 / 300 loss: [-3.60244242e-18]
# Epoch 742: Accuracy 230 / 300 loss: [1.72026745e-19]
# Epoch 743: Accuracy 230 / 300 loss: [2.75387352e-18]
# Epoch 744: Accuracy 230 / 300 loss: [-8.95550994e-18]
# Epoch 745: Accuracy 230 / 300 loss: [9.49471983e-18]
# Epoch 746: Accuracy 230 / 300 loss: [1.4484941e-18]
# Epoch 747: Accuracy 230 / 300 loss: [-1.42970126e-18]
# Epoch 748: Accuracy 230 / 300 loss: [1.07422751e-17]
# Epoch 749: Accuracy 230 / 300 loss: [3.31332184e-18]
# Epoch 750: Accuracy 230 / 300 loss: [1.35481903e-17]
# Epoch 751: Accuracy 230 / 300 loss: [-4.68809019e-18]
# Epoch 752: Accuracy 230 / 300 loss: [1.67342991e-17]
# Epoch 753: Accuracy 230 / 300 loss: [-3.93637669e-18]
# Epoch 754: Accuracy 230 / 300 loss: [-6.57749318e-19]
# Epoch 755: Accuracy 230 / 300 loss: [-1.06280725e-17]
# Epoch 756: Accuracy 230 / 300 loss: [1.31651056e-17]
# Epoch 757: Accuracy 230 / 300 loss: [-1.46005893e-18]
# Epoch 758: Accuracy 230 / 300 loss: [-7.84095011e-18]
# Epoch 759: Accuracy 230 / 300 loss: [2.73218947e-18]
# Epoch 760: Accuracy 230 / 300 loss: [2.72640706e-18]
# Epoch 761: Accuracy 230 / 300 loss: [-9.73902671e-18]
# Epoch 762: Accuracy 230 / 300 loss: [8.47123297e-19]
# Epoch 763: Accuracy 230 / 300 loss: [-2.00071441e-18]
# Epoch 764: Accuracy 230 / 300 loss: [-8.4365385e-18]
# Epoch 765: Accuracy 230 / 300 loss: [-5.56990796e-18]
# Epoch 766: Accuracy 230 / 300 loss: [7.14272391e-18]
# Epoch 767: Accuracy 230 / 300 loss: [1.40657162e-18]
# Epoch 768: Accuracy 230 / 300 loss: [9.0350181e-19]
# Epoch 769: Accuracy 230 / 300 loss: [9.79395962e-18]
# Epoch 770: Accuracy 230 / 300 loss: [1.34151949e-18]
# Epoch 771: Accuracy 230 / 300 loss: [5.8402357e-18]
# Epoch 772: Accuracy 230 / 300 loss: [2.43150407e-18]
# Epoch 773: Accuracy 230 / 300 loss: [-6.16838756e-18]
# Epoch 774: Accuracy 230 / 300 loss: [-1.06598758e-17]
# Epoch 775: Accuracy 230 / 300 loss: [-1.19811568e-17]
# Epoch 776: Accuracy 230 / 300 loss: [1.20765666e-17]
# Epoch 777: Accuracy 230 / 300 loss: [-6.9851532e-18]
# Epoch 778: Accuracy 230 / 300 loss: [-2.00389474e-17]
# Epoch 779: Accuracy 229 / 300 loss: [-1.64856554e-17]
# Epoch 780: Accuracy 229 / 300 loss: [-2.93312828e-18]
# Epoch 781: Accuracy 229 / 300 loss: [5.70724024e-18]
# Epoch 782: Accuracy 229 / 300 loss: [-3.72098186e-18]
# Epoch 783: Accuracy 229 / 300 loss: [-2.24068449e-20]
# Epoch 784: Accuracy 229 / 300 loss: [1.86555054e-18]
# Epoch 785: Accuracy 229 / 300 loss: [6.50738144e-18]
# Epoch 786: Accuracy 229 / 300 loss: [1.28145469e-17]
# Epoch 787: Accuracy 229 / 300 loss: [-1.3549636e-17]
# Epoch 788: Accuracy 229 / 300 loss: [1.98047597e-18]
# Epoch 789: Accuracy 229 / 300 loss: [2.82326246e-18]
# Epoch 790: Accuracy 229 / 300 loss: [-1.10097117e-17]
# Epoch 791: Accuracy 229 / 300 loss: [-1.86150285e-17]
# Epoch 792: Accuracy 229 / 300 loss: [5.90095102e-18]
# Epoch 793: Accuracy 229 / 300 loss: [-8.87455618e-18]
# Epoch 794: Accuracy 229 / 300 loss: [-1.26497481e-17]
# Epoch 795: Accuracy 229 / 300 loss: [3.11093743e-18]
# Epoch 796: Accuracy 229 / 300 loss: [-1.25868644e-17]
# Epoch 797: Accuracy 229 / 300 loss: [3.48896259e-18]
# Epoch 798: Accuracy 229 / 300 loss: [-1.11672824e-17]
# Epoch 799: Accuracy 229 / 300 loss: [-1.9978232e-18]
# Epoch 800: Accuracy 229 / 300 loss: [7.96527196e-19]
# Epoch 801: Accuracy 229 / 300 loss: [-3.07335176e-18]
# Epoch 802: Accuracy 229 / 300 loss: [-3.25549772e-18]
# Epoch 803: Accuracy 229 / 300 loss: [1.41394419e-17]
# Epoch 804: Accuracy 229 / 300 loss: [3.66026653e-18]
# Epoch 805: Accuracy 229 / 300 loss: [-8.76613597e-18]
# Epoch 806: Accuracy 229 / 300 loss: [-8.64109131e-18]
# Epoch 807: Accuracy 229 / 300 loss: [-4.48064618e-18]
# Epoch 808: Accuracy 229 / 300 loss: [-9.54097912e-20]
# Epoch 809: Accuracy 229 / 300 loss: [5.2403105e-19]
# Epoch 810: Accuracy 229 / 300 loss: [-6.07153217e-19]
# Epoch 811: Accuracy 229 / 300 loss: [-6.74446031e-18]
# Epoch 812: Accuracy 229 / 300 loss: [2.96565434e-18]
# Epoch 813: Accuracy 229 / 300 loss: [9.63494331e-19]
# Epoch 814: Accuracy 229 / 300 loss: [5.39426721e-18]
# Epoch 815: Accuracy 229 / 300 loss: [1.095767e-18]
# Epoch 816: Accuracy 229 / 300 loss: [-1.20274161e-17]
# Epoch 817: Accuracy 229 / 300 loss: [-1.09236983e-17]
# Epoch 818: Accuracy 229 / 300 loss: [-7.9334687e-18]
# Epoch 819: Accuracy 229 / 300 loss: [-7.37112917e-18]
# Epoch 820: Accuracy 229 / 300 loss: [-2.6931582e-18]
# Epoch 821: Accuracy 229 / 300 loss: [-3.1456319e-18]
# Epoch 822: Accuracy 229 / 300 loss: [-7.46220215e-18]
# Epoch 823: Accuracy 229 / 300 loss: [-1.53407379e-17]
# Epoch 824: Accuracy 229 / 300 loss: [-2.08470394e-17]
# Epoch 825: Accuracy 229 / 300 loss: [6.8890206e-18]
# Epoch 826: Accuracy 229 / 300 loss: [7.06177015e-19]
# Epoch 827: Accuracy 229 / 300 loss: [4.72856707e-18]
# Epoch 828: Accuracy 229 / 300 loss: [-1.17296219e-17]
# Epoch 829: Accuracy 229 / 300 loss: [1.66533454e-18]
# Epoch 830: Accuracy 229 / 300 loss: [-2.56160833e-18]
# Epoch 831: Accuracy 229 / 300 loss: [6.04262011e-18]
# Epoch 832: Accuracy 229 / 300 loss: [1.28318941e-17]
# Epoch 833: Accuracy 230 / 300 loss: [1.6774776e-17]
# Epoch 834: Accuracy 230 / 300 loss: [-1.04068953e-17]
# Epoch 835: Accuracy 230 / 300 loss: [-2.2075079e-17]
# Epoch 836: Accuracy 230 / 300 loss: [-1.598114e-18]
# Epoch 837: Accuracy 230 / 300 loss: [5.63640569e-18]
# Epoch 838: Accuracy 230 / 300 loss: [1.58871758e-18]
# Epoch 839: Accuracy 230 / 300 loss: [1.39739204e-17]
# Epoch 840: Accuracy 230 / 300 loss: [4.11996826e-19]
# Epoch 841: Accuracy 230 / 300 loss: [2.88831459e-18]
# Epoch 842: Accuracy 230 / 300 loss: [6.97069717e-18]
# Epoch 843: Accuracy 230 / 300 loss: [-6.12646508e-18]
# Epoch 844: Accuracy 230 / 300 loss: [8.09176221e-18]
# Epoch 845: Accuracy 230 / 300 loss: [8.91358746e-18]
# Epoch 846: Accuracy 230 / 300 loss: [-5.75349953e-18]
# Epoch 847: Accuracy 230 / 300 loss: [-7.14778352e-18]
# Epoch 848: Accuracy 230 / 300 loss: [8.57603918e-18]
# Epoch 849: Accuracy 230 / 300 loss: [-5.3415027e-19]
# Epoch 850: Accuracy 230 / 300 loss: [-3.42752447e-18]
# Epoch 851: Accuracy 230 / 300 loss: [1.09439367e-17]
# Epoch 852: Accuracy 230 / 300 loss: [-2.59991681e-18]
# Epoch 853: Accuracy 230 / 300 loss: [-3.00034881e-18]
# Epoch 854: Accuracy 230 / 300 loss: [-8.09248502e-18]
# Epoch 855: Accuracy 230 / 300 loss: [7.79902763e-19]
# Epoch 856: Accuracy 230 / 300 loss: [9.54531593e-18]
# Epoch 857: Accuracy 230 / 300 loss: [1.59507824e-17]
# Epoch 858: Accuracy 230 / 300 loss: [8.71626267e-18]
# Epoch 859: Accuracy 230 / 300 loss: [4.56593675e-18]
# Epoch 860: Accuracy 230 / 300 loss: [4.88758339e-18]
# Epoch 861: Accuracy 230 / 300 loss: [3.61183884e-18]
# Epoch 862: Accuracy 230 / 300 loss: [8.60133724e-20]
# Epoch 863: Accuracy 230 / 300 loss: [-4.11057184e-18]
# Epoch 864: Accuracy 230 / 300 loss: [3.25983453e-18]
# Epoch 865: Accuracy 230 / 300 loss: [5.95660674e-18]
# Epoch 866: Accuracy 230 / 300 loss: [6.91937826e-18]
# Epoch 867: Accuracy 230 / 300 loss: [-1.9443359e-19]
# Epoch 868: Accuracy 230 / 300 loss: [-3.49980461e-18]
# Epoch 869: Accuracy 230 / 300 loss: [3.55473752e-18]
# Epoch 870: Accuracy 230 / 300 loss: [-1.25478331e-18]
# Epoch 871: Accuracy 230 / 300 loss: [4.76687555e-18]
# Epoch 872: Accuracy 230 / 300 loss: [-9.15789435e-19]
# Epoch 873: Accuracy 230 / 300 loss: [-7.45136013e-18]
# Epoch 874: Accuracy 230 / 300 loss: [-4.09683861e-18]
# Epoch 875: Accuracy 230 / 300 loss: [-2.12214505e-18]
# Epoch 876: Accuracy 230 / 300 loss: [7.06899816e-19]
# Epoch 877: Accuracy 230 / 300 loss: [2.82976767e-18]
# Epoch 878: Accuracy 230 / 300 loss: [1.09815224e-17]
# Epoch 879: Accuracy 230 / 300 loss: [3.38415638e-18]
# Epoch 880: Accuracy 230 / 300 loss: [-1.36898594e-18]
# Epoch 881: Accuracy 230 / 300 loss: [1.67689936e-19]
# Epoch 882: Accuracy 230 / 300 loss: [-9.49616543e-18]
# Epoch 883: Accuracy 230 / 300 loss: [3.61978965e-18]
# Epoch 884: Accuracy 230 / 300 loss: [3.42607887e-18]
# Epoch 885: Accuracy 230 / 300 loss: [-4.88324658e-18]
# Epoch 886: Accuracy 230 / 300 loss: [5.25548933e-18]
# Epoch 887: Accuracy 230 / 300 loss: [7.01117405e-18]
# Epoch 888: Accuracy 230 / 300 loss: [8.07369218e-18]
# Epoch 889: Accuracy 230 / 300 loss: [-5.45859654e-18]
# Epoch 890: Accuracy 230 / 300 loss: [-9.4311133e-18]
# Epoch 891: Accuracy 230 / 300 loss: [4.00142882e-18]
# Epoch 892: Accuracy 230 / 300 loss: [-7.81131525e-18]
# Epoch 893: Accuracy 230 / 300 loss: [1.01560832e-17]
# Epoch 894: Accuracy 230 / 300 loss: [-7.86986217e-18]
# Epoch 895: Accuracy 230 / 300 loss: [-3.33717429e-18]
# Epoch 896: Accuracy 230 / 300 loss: [4.65700973e-18]
# Epoch 897: Accuracy 230 / 300 loss: [-1.10183853e-17]
# Epoch 898: Accuracy 230 / 300 loss: [-7.08923661e-18]
# Epoch 899: Accuracy 230 / 300 loss: [1.84964891e-18]
# ...
# Epoch 4708: Accuracy 251 / 300 loss: [-2.20978473e-18]
# Epoch 4709: Accuracy 255 / 300 loss: [8.74160024e-18]
# Epoch 4710: Accuracy 251 / 300 loss: [-4.5198518e-18]
# Epoch 4711: Accuracy 255 / 300 loss: [-7.97713607e-18]
# Epoch 4712: Accuracy 251 / 300 loss: [-2.54747276e-19]
# Epoch 4713: Accuracy 255 / 300 loss: [-4.98008786e-19]
# Epoch 4714: Accuracy 251 / 300 loss: [-1.36751578e-17]
# Epoch 4715: Accuracy 255 / 300 loss: [1.62405919e-17]
# Epoch 4716: Accuracy 251 / 300 loss: [2.04546316e-18]
# Epoch 4717: Accuracy 255 / 300 loss: [1.23416272e-17]
# Epoch 4978: Accuracy 251 / 300 loss: [-1.77831956e-18]
# Epoch 4979: Accuracy 253 / 300 loss: [5.65273649e-18]
# Epoch 4980: Accuracy 251 / 300 loss: [-9.37132407e-18]
# Epoch 4981: Accuracy 253 / 300 loss: [9.64644037e-18]
# Epoch 4982: Accuracy 251 / 300 loss: [1.56663021e-17]
# Epoch 4983: Accuracy 253 / 300 loss: [1.12527021e-17]
# Epoch 4984: Accuracy 251 / 300 loss: [-4.5465044e-18]
# Epoch 4985: Accuracy 253 / 300 loss: [-5.91884883e-18]
# Epoch 4986: Accuracy 251 / 300 loss: [1.86664978e-17]
# Epoch 4987: Accuracy 253 / 300 loss: [-1.89930593e-17]
# Epoch 4988: Accuracy 251 / 300 loss: [2.32824991e-17]
# Epoch 4989: Accuracy 253 / 300 loss: [4.58003208e-18]
# Epoch 4990: Accuracy 251 / 300 loss: [2.68460881e-18]
# Epoch 4991: Accuracy 253 / 300 loss: [2.12981014e-17]
# Epoch 4992: Accuracy 251 / 300 loss: [1.09412093e-18]
# Epoch 4993: Accuracy 253 / 300 loss: [-6.92193066e-18]
# Epoch 4994: Accuracy 251 / 300 loss: [-1.00336587e-17]
# Epoch 4995: Accuracy 253 / 300 loss: [-9.94641991e-18]
# Epoch 4996: Accuracy 251 / 300 loss: [8.75294343e-18]
# Epoch 4997: Accuracy 253 / 300 loss: [-1.9729769e-18]
# Epoch 4998: Accuracy 251 / 300 loss: [-4.39249122e-18]
# Epoch 4999: Accuracy 253 / 300 loss: [-2.15539674e-18]
# Model with highest accuracy 0.8533333333333334 achieved at epoch 3407

# %%
# We get the cost and accuracy during training 
# by referencing the nnet object's attributes costs and accuracies which we give to the visualization function
losses_training = nnet.losses
accuracy_training = nnet.accuracies
visualize_cost_accuracy_curves(accuracy_training, losses_training)
# we give the nnet object to the second visualization function to visualize the estimated posterior
visualize_posterior(nnet)
# Out:
# best_accuracy: 0.8533333333333334 achieved at epoch: 3395

# %% [markdown]
# <a id='Train2'></a>
# ## Train a network with ReLU activation functions.
# Define a new network with the same number of nodes and name it nnet_2 in order to avoid erasing the previous model. Once the training is completed visualize the cost / accuracy curves and the estimated posterior using the provided code.

# %%
nnodes = [2, 10, 10, 2]
learning_rate = 0.2
epochs = 5000 
############ TO DO Q2d ############################

activation_functions2 = 'relu' 
nnet_2 = NeuralNetwork(nnodes, activation_functions2)

nnet_2.gradient_descent(train_data, epochs, learning_rate, test_data)

###########  TO DO Q2d ###########################
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch 1: Accuracy 167 / 300 loss: [7.08050398e-17]
# Epoch 2: Accuracy 159 / 300 loss: [2.71891353e-17]
# Epoch 3: Accuracy 185 / 300 loss: [-4.64481061e-17]
# Epoch 4: Accuracy 174 / 300 loss: [-4.41823449e-17]
# Epoch 5: Accuracy 193 / 300 loss: [1.35945676e-17]
# Epoch 6: Accuracy 181 / 300 loss: [2.26576127e-18]
# Epoch 7: Accuracy 196 / 300 loss: [0.]
# Epoch 8: Accuracy 170 / 300 loss: [1.2461687e-17]
# Epoch 9: Accuracy 200 / 300 loss: [0.]
# Epoch 10: Accuracy 193 / 300 loss: [1.81260902e-17]
# Epoch 11: Accuracy 203 / 300 loss: [-9.0630451e-18]
# Epoch 12: Accuracy 215 / 300 loss: [-1.58603289e-17]
# Epoch 13: Accuracy 208 / 300 loss: [2.94548966e-17]
# Epoch 14: Accuracy 223 / 300 loss: [2.26576127e-18]
# Epoch 15: Accuracy 222 / 300 loss: [-3.28535385e-17]
# Epoch 16: Accuracy 225 / 300 loss: [2.60562547e-17]
# Epoch 17: Accuracy 229 / 300 loss: [-4.53152255e-17]
# Epoch 18: Accuracy 228 / 300 loss: [4.53152255e-18]
# Epoch 19: Accuracy 225 / 300 loss: [1.13288064e-17]
# Epoch 20: Accuracy 224 / 300 loss: [-1.13288064e-18]
# Epoch 21: Accuracy 224 / 300 loss: [1.01959257e-17]
# Epoch 22: Accuracy 225 / 300 loss: [-9.0630451e-18]
# Epoch 23: Accuracy 223 / 300 loss: [-2.26576127e-18]
# Epoch 24: Accuracy 219 / 300 loss: [4.19165836e-17]
# Epoch 25: Accuracy 222 / 300 loss: [1.35945676e-17]
# Epoch 26: Accuracy 214 / 300 loss: [-4.53152255e-18]
# Epoch 27: Accuracy 215 / 300 loss: [-2.26576127e-18]
# Epoch 28: Accuracy 213 / 300 loss: [2.71891353e-17]
# Epoch 29: Accuracy 215 / 300 loss: [-2.60562547e-17]
# Epoch 30: Accuracy 214 / 300 loss: [-2.71891353e-17]
# Epoch 31: Accuracy 212 / 300 loss: [-3.39864191e-17]
# Epoch 32: Accuracy 216 / 300 loss: [-1.47274483e-17]
# Epoch 33: Accuracy 212 / 300 loss: [-1.07623661e-17]
# Epoch 34: Accuracy 214 / 300 loss: [-7.93016446e-18]
# Epoch 35: Accuracy 214 / 300 loss: [2.26576127e-17]
# Epoch 36: Accuracy 213 / 300 loss: [1.69932096e-17]
# Epoch 37: Accuracy 213 / 300 loss: [4.53152255e-18]
# Epoch 38: Accuracy 211 / 300 loss: [-2.26576127e-17]
# Epoch 39: Accuracy 211 / 300 loss: [-1.13288064e-17]
# Epoch 40: Accuracy 211 / 300 loss: [-6.79728382e-18]
# Epoch 41: Accuracy 211 / 300 loss: [1.69932096e-18]
# Epoch 42: Accuracy 211 / 300 loss: [3.39864191e-18]
# Epoch 43: Accuracy 211 / 300 loss: [-8.49660478e-18]
# Epoch 44: Accuracy 208 / 300 loss: [2.71891353e-17]
# Epoch 45: Accuracy 211 / 300 loss: [-1.98254112e-17]
# Epoch 46: Accuracy 207 / 300 loss: [2.32240531e-17]
# Epoch 47: Accuracy 211 / 300 loss: [5.09796287e-18]
# Epoch 48: Accuracy 205 / 300 loss: [2.26576127e-18]
# Epoch 49: Accuracy 212 / 300 loss: [1.2461687e-17]
# Epoch 50: Accuracy 205 / 300 loss: [-3.62521804e-17]
# Epoch 51: Accuracy 212 / 300 loss: [-5.09796287e-18]
# Epoch 52: Accuracy 204 / 300 loss: [2.4923374e-17]
# Epoch 53: Accuracy 213 / 300 loss: [-1.21784669e-17]
# Epoch 54: Accuracy 203 / 300 loss: [6.51406366e-18]
# Epoch 55: Accuracy 213 / 300 loss: [-2.15247321e-17]
# Epoch 56: Accuracy 203 / 300 loss: [1.2461687e-17]
# Epoch 57: Accuracy 212 / 300 loss: [-1.13288064e-18]
# Epoch 58: Accuracy 201 / 300 loss: [2.83220159e-17]
# Epoch 59: Accuracy 212 / 300 loss: [1.52938886e-17]
# Epoch 60: Accuracy 201 / 300 loss: [8.77982494e-18]
# Epoch 61: Accuracy 212 / 300 loss: [6.79728382e-18]
# Epoch 62: Accuracy 201 / 300 loss: [2.29408329e-17]
# Epoch 63: Accuracy 213 / 300 loss: [8.49660478e-19]
# Epoch 64: Accuracy 200 / 300 loss: [8.21338462e-18]
# Epoch 65: Accuracy 212 / 300 loss: [-1.47274483e-17]
# Epoch 66: Accuracy 199 / 300 loss: [1.35945676e-17]
# Epoch 67: Accuracy 212 / 300 loss: [-7.08050398e-18]
# Epoch 68: Accuracy 200 / 300 loss: [1.2461687e-17]
# Epoch 69: Accuracy 213 / 300 loss: [3.3703199e-17]
# Epoch 70: Accuracy 197 / 300 loss: [3.11542175e-18]
# Epoch 71: Accuracy 217 / 300 loss: [-1.69932096e-18]
# Epoch 72: Accuracy 193 / 300 loss: [1.47274483e-17]
# Epoch 73: Accuracy 218 / 300 loss: [1.16120265e-17]
# Epoch 74: Accuracy 196 / 300 loss: [2.54898143e-18]
# Epoch 75: Accuracy 218 / 300 loss: [-1.48690584e-17]
# Epoch 76: Accuracy 194 / 300 loss: [1.784287e-17]
# Epoch 77: Accuracy 219 / 300 loss: [3.54025199e-17]
# Epoch 78: Accuracy 190 / 300 loss: [-1.92589708e-17]
# Epoch 79: Accuracy 221 / 300 loss: [5.66440319e-18]
# Epoch 80: Accuracy 188 / 300 loss: [-8.49660478e-19]
# Epoch 81: Accuracy 221 / 300 loss: [2.27992228e-17]
# Epoch 82: Accuracy 184 / 300 loss: [2.44985438e-17]
# Epoch 83: Accuracy 219 / 300 loss: [-1.65683793e-17]
# Epoch 84: Accuracy 181 / 300 loss: [-2.86052361e-17]
# Epoch 85: Accuracy 220 / 300 loss: [-5.38118303e-18]
# Epoch 86: Accuracy 182 / 300 loss: [-2.27992228e-17]
# Epoch 87: Accuracy 221 / 300 loss: [5.19708992e-17]
# Epoch 88: Accuracy 181 / 300 loss: [-1.84093104e-18]
# Epoch 89: Accuracy 221 / 300 loss: [-6.08923343e-18]
# Epoch 90: Accuracy 182 / 300 loss: [1.07623661e-17]
# Epoch 91: Accuracy 225 / 300 loss: [-1.99670212e-17]
# Epoch 92: Accuracy 179 / 300 loss: [-2.40737135e-18]
# Epoch 93: Accuracy 223 / 300 loss: [-2.53482043e-17]
# Epoch 94: Accuracy 180 / 300 loss: [1.27449072e-17]
# Epoch 95: Accuracy 223 / 300 loss: [9.34626526e-18]
# Epoch 96: Accuracy 183 / 300 loss: [2.44985438e-17]
# Epoch 97: Accuracy 223 / 300 loss: [2.19495623e-17]
# Epoch 98: Accuracy 188 / 300 loss: [-2.19495623e-17]
# Epoch 188: Accuracy 210 / 300 loss: [-5.66440319e-18]
# Epoch 189: Accuracy 218 / 300 loss: [1.55771088e-17]
# Epoch 190: Accuracy 213 / 300 loss: [-4.24830239e-19]
# Epoch 191: Accuracy 218 / 300 loss: [-1.45858382e-17]
# Epoch 192: Accuracy 212 / 300 loss: [-4.10669231e-18]
# Epoch 193: Accuracy 217 / 300 loss: [1.69932096e-18]
# Epoch 194: Accuracy 212 / 300 loss: [2.40737135e-18]
# Epoch 195: Accuracy 218 / 300 loss: [-5.80601327e-18]
# Epoch 196: Accuracy 214 / 300 loss: [4.67313263e-18]
# Epoch 197: Accuracy 216 / 300 loss: [2.29408329e-17]
# Epoch 198: Accuracy 212 / 300 loss: [2.33656631e-17]
# Epoch 199: Accuracy 217 / 300 loss: [-4.95635279e-17]
# Epoch 200: Accuracy 212 / 300 loss: [-2.61270597e-17]
# Epoch 201: Accuracy 218 / 300 loss: [-3.39864191e-18]
# Epoch 202: Accuracy 213 / 300 loss: [2.20911724e-17]
# Epoch 203: Accuracy 221 / 300 loss: [6.51406366e-18]
# Epoch 204: Accuracy 208 / 300 loss: [1.6072744e-17]
# Epoch 205: Accuracy 221 / 300 loss: [-2.83220159e-18]
# Epoch 206: Accuracy 207 / 300 loss: [-3.69602308e-17]
# Epoch 207: Accuracy 220 / 300 loss: [1.88341406e-17]
# Epoch 208: Accuracy 205 / 300 loss: [8.03637202e-18]
# Epoch 209: Accuracy 221 / 300 loss: [5.80601327e-18]
# Epoch 210: Accuracy 204 / 300 loss: [4.60232759e-18]
# Epoch 211: Accuracy 223 / 300 loss: [2.03918515e-17]
# Epoch 212: Accuracy 205 / 300 loss: [4.18457785e-17]
# Epoch 213: Accuracy 221 / 300 loss: [1.07623661e-17]
# Epoch 214: Accuracy 204 / 300 loss: [1.99670212e-17]
# Epoch 215: Accuracy 221 / 300 loss: [1.98254112e-18]
# Epoch 216: Accuracy 205 / 300 loss: [-5.3387e-17]
# Epoch 217: Accuracy 220 / 300 loss: [1.74180398e-17]
# Epoch 218: Accuracy 205 / 300 loss: [-1.04968472e-17]
# Epoch 219: Accuracy 222 / 300 loss: [2.10999019e-17]
# Epoch 220: Accuracy 204 / 300 loss: [3.41280292e-17]
# Epoch 221: Accuracy 220 / 300 loss: [-7.08050398e-19]
# Epoch 222: Accuracy 204 / 300 loss: [-2.09582918e-17]
# Epoch 223: Accuracy 220 / 300 loss: [-1.2461687e-17]
# Epoch 224: Accuracy 205 / 300 loss: [2.75254592e-17]
# Epoch 225: Accuracy 220 / 300 loss: [-1.98254112e-18]
# Epoch 226: Accuracy 204 / 300 loss: [-7.25751658e-18]
# Epoch 227: Accuracy 221 / 300 loss: [1.52938886e-17]
# Epoch 228: Accuracy 206 / 300 loss: [-1.1505819e-17]
# Epoch 229: Accuracy 219 / 300 loss: [3.11542175e-18]
# Epoch 230: Accuracy 206 / 300 loss: [-4.14209483e-17]
# Epoch 231: Accuracy 220 / 300 loss: [-6.08923343e-18]
# Epoch 232: Accuracy 210 / 300 loss: [1.4161008e-17]
# Epoch 233: Accuracy 219 / 300 loss: [2.97381167e-18]
# Epoch 234: Accuracy 206 / 300 loss: [2.36488833e-17]
# Epoch 235: Accuracy 221 / 300 loss: [1.21784669e-17]
# Epoch 236: Accuracy 212 / 300 loss: [2.17371472e-17]
# Epoch 237: Accuracy 219 / 300 loss: [-1.94005809e-17]
# Epoch 238: Accuracy 208 / 300 loss: [-4.92803077e-17]
# Epoch 239: Accuracy 221 / 300 loss: [2.43569337e-17]
# Epoch 240: Accuracy 210 / 300 loss: [-5.31037799e-18]
# Epoch 241: Accuracy 222 / 300 loss: [7.93016446e-18]
# Epoch 242: Accuracy 208 / 300 loss: [-8.49660478e-19]
# Epoch 243: Accuracy 219 / 300 loss: [-2.69059151e-18]
# Epoch 244: Accuracy 208 / 300 loss: [-1.29927248e-17]
# Epoch 245: Accuracy 221 / 300 loss: [1.48690584e-17]
# Epoch 246: Accuracy 208 / 300 loss: [-2.38612984e-17]
# Epoch 247: Accuracy 222 / 300 loss: [1.01959257e-17]
# Epoch 248: Accuracy 206 / 300 loss: [1.68693007e-17]
# Epoch 249: Accuracy 222 / 300 loss: [4.13501433e-17]
# Epoch 250: Accuracy 205 / 300 loss: [2.73484466e-17]
# Epoch 251: Accuracy 222 / 300 loss: [4.53152255e-17]
# Epoch 252: Accuracy 206 / 300 loss: [8.3549947e-18]
# Epoch 253: Accuracy 222 / 300 loss: [-3.07293873e-17]
# Epoch 254: Accuracy 205 / 300 loss: [-1.6001939e-17]
# Epoch 255: Accuracy 221 / 300 loss: [-3.0162947e-17]
# Epoch 256: Accuracy 205 / 300 loss: [-7.71774934e-18]
# Epoch 257: Accuracy 221 / 300 loss: [3.22870982e-17]
# Epoch 258: Accuracy 205 / 300 loss: [-8.49660478e-18]
# Epoch 259: Accuracy 220 / 300 loss: [-2.15247321e-17]
# Epoch 260: Accuracy 207 / 300 loss: [5.31037799e-18]
# Epoch 261: Accuracy 219 / 300 loss: [-1.84093104e-18]
# Epoch 262: Accuracy 208 / 300 loss: [-3.78806963e-18]
# Epoch 263: Accuracy 220 / 300 loss: [2.33656631e-17]
# Epoch 264: Accuracy 210 / 300 loss: [9.09844762e-18]
# Epoch 265: Accuracy 219 / 300 loss: [-3.0162947e-17]
# Epoch 266: Accuracy 211 / 300 loss: [2.14893296e-17]
# Epoch 267: Accuracy 218 / 300 loss: [-2.54898143e-18]
# Epoch 268: Accuracy 212 / 300 loss: [1.37007752e-17]
# Epoch 269: Accuracy 219 / 300 loss: [-1.55771088e-18]
# Epoch 270: Accuracy 211 / 300 loss: [2.10822006e-17]
# Epoch 271: Accuracy 220 / 300 loss: [-2.1383122e-17]
# Epoch 272: Accuracy 204 / 300 loss: [-9.00994132e-18]
# Epoch 273: Accuracy 224 / 300 loss: [-1.57187188e-17]
# Epoch 274: Accuracy 206 / 300 loss: [2.94902991e-17]
# Epoch 275: Accuracy 220 / 300 loss: [-1.35945676e-17]
# Epoch 276: Accuracy 206 / 300 loss: [9.27546022e-18]
# Epoch 277: Accuracy 221 / 300 loss: [4.24830239e-19]
# Epoch 278: Accuracy 206 / 300 loss: [-5.13336539e-18]
# Epoch 279: Accuracy 220 / 300 loss: [1.11871963e-17]
# Epoch 280: Accuracy 205 / 300 loss: [3.39864191e-18]
# Epoch 281: Accuracy 221 / 300 loss: [-3.04461671e-17]
# Epoch 282: Accuracy 207 / 300 loss: [3.39864191e-18]
# Epoch 283: Accuracy 221 / 300 loss: [4.24830239e-19]
# Epoch 284: Accuracy 207 / 300 loss: [3.78275925e-17]
# Epoch 285: Accuracy 220 / 300 loss: [4.24830239e-19]
# Epoch 286: Accuracy 208 / 300 loss: [1.98254112e-18]
# Epoch 287: Accuracy 220 / 300 loss: [-4.27662441e-17]
# Epoch 288: Accuracy 204 / 300 loss: [-3.03399596e-17]
# Epoch 289: Accuracy 222 / 300 loss: [-2.06750716e-17]
# Epoch 290: Accuracy 206 / 300 loss: [-3.46944695e-17]
# Epoch 291: Accuracy 219 / 300 loss: [-5.09796287e-18]
# Epoch 292: Accuracy 205 / 300 loss: [8.51430604e-18]
# Epoch 293: Accuracy 221 / 300 loss: [-1.65683793e-17]
# Epoch 294: Accuracy 205 / 300 loss: [-2.17548485e-17]
# Epoch 295: Accuracy 221 / 300 loss: [3.65354006e-17]
# Epoch 296: Accuracy 207 / 300 loss: [2.09582918e-17]
# Epoch 297: Accuracy 221 / 300 loss: [3.00213369e-17]
# Epoch 298: Accuracy 208 / 300 loss: [7.78855438e-18]
# Epoch 299: Accuracy 220 / 300 loss: [1.20368568e-18]
# Epoch 300: Accuracy 205 / 300 loss: [-8.1779821e-18]
# Epoch 301: Accuracy 223 / 300 loss: [-1.57187188e-17]
# Epoch 302: Accuracy 207 / 300 loss: [1.35591651e-17]
# Epoch 303: Accuracy 220 / 300 loss: [-8.77982494e-18]
# Epoch 304: Accuracy 206 / 300 loss: [-2.08166817e-17]
# Epoch 305: Accuracy 221 / 300 loss: [-1.09039761e-17]
# Epoch 306: Accuracy 206 / 300 loss: [1.75419486e-17]
# Epoch 307: Accuracy 220 / 300 loss: [-1.98254112e-18]
# Epoch 308: Accuracy 207 / 300 loss: [-2.33125594e-17]
# Epoch 309: Accuracy 220 / 300 loss: [2.43569337e-17]
# Epoch 310: Accuracy 206 / 300 loss: [-1.4161008e-19]
# Epoch 311: Accuracy 221 / 300 loss: [1.72764297e-17]
# Epoch 312: Accuracy 206 / 300 loss: [-1.80641358e-17]
# Epoch 313: Accuracy 223 / 300 loss: [-2.93132865e-17]
# Epoch 314: Accuracy 208 / 300 loss: [1.87102318e-17]
# Epoch 315: Accuracy 221 / 300 loss: [-5.16876791e-18]
# Epoch 316: Accuracy 205 / 300 loss: [-1.92589708e-17]
# Epoch 317: Accuracy 221 / 300 loss: [1.96838011e-17]
# Epoch 318: Accuracy 209 / 300 loss: [-5.84141579e-19]
# Epoch 319: Accuracy 220 / 300 loss: [9.0630451e-18]
# Epoch 320: Accuracy 207 / 300 loss: [-5.55819563e-18]
# Epoch 321: Accuracy 221 / 300 loss: [3.75266711e-17]
# Epoch 322: Accuracy 210 / 300 loss: [-1.61081466e-17]
# Epoch 323: Accuracy 220 / 300 loss: [9.20465518e-18]
# Epoch 324: Accuracy 206 / 300 loss: [-1.80552852e-18]
# Epoch 325: Accuracy 220 / 300 loss: [9.48787534e-18]
# Epoch 326: Accuracy 205 / 300 loss: [-2.83220159e-17]
# Epoch 327: Accuracy 224 / 300 loss: [1.01959257e-17]
# Epoch 328: Accuracy 204 / 300 loss: [-3.51901048e-17]
# Epoch 329: Accuracy 223 / 300 loss: [-2.10999019e-17]
# Epoch 330: Accuracy 204 / 300 loss: [1.05499509e-17]
# Epoch 331: Accuracy 222 / 300 loss: [-1.61435491e-17]
# Epoch 332: Accuracy 204 / 300 loss: [-3.02160507e-17]
# Epoch 333: Accuracy 222 / 300 loss: [-1.784287e-17]
# Epoch 334: Accuracy 205 / 300 loss: [1.4161008e-17]
# Epoch 335: Accuracy 224 / 300 loss: [5.66440319e-19]
# Epoch 336: Accuracy 206 / 300 loss: [1.64267692e-17]
# Epoch 337: Accuracy 224 / 300 loss: [3.27119284e-17]
# Epoch 338: Accuracy 206 / 300 loss: [1.55771088e-18]
# Epoch 339: Accuracy 223 / 300 loss: [-2.26576127e-18]
# Epoch 340: Accuracy 205 / 300 loss: [-5.46968933e-18]
# Epoch 341: Accuracy 221 / 300 loss: [-1.65683793e-17]
# Epoch 342: Accuracy 202 / 300 loss: [-5.52279311e-18]
# Epoch 343: Accuracy 222 / 300 loss: [1.84093104e-18]
# Epoch 344: Accuracy 209 / 300 loss: [2.76936212e-17]
# Epoch 345: Accuracy 220 / 300 loss: [-7.50533422e-18]
# Epoch 346: Accuracy 214 / 300 loss: [2.37550909e-17]
# Epoch 347: Accuracy 217 / 300 loss: [-1.75596499e-17]
# Epoch 348: Accuracy 217 / 300 loss: [-3.35615889e-17]
# Epoch 349: Accuracy 217 / 300 loss: [-2.96673117e-17]
# Epoch 350: Accuracy 217 / 300 loss: [5.94762335e-18]
# Epoch 351: Accuracy 217 / 300 loss: [9.34626526e-18]
# Epoch 352: Accuracy 216 / 300 loss: [-5.82371453e-18]
# Epoch 353: Accuracy 220 / 300 loss: [2.86760411e-18]
# Epoch 354: Accuracy 218 / 300 loss: [1.37361777e-17]
# Epoch 355: Accuracy 217 / 300 loss: [3.92967971e-18]
# Epoch 356: Accuracy 214 / 300 loss: [2.33656631e-17]
# Epoch 357: Accuracy 220 / 300 loss: [-5.49447109e-17]
# Epoch 358: Accuracy 208 / 300 loss: [3.23225007e-17]
# Epoch 359: Accuracy 220 / 300 loss: [1.79136751e-17]
# Epoch 360: Accuracy 205 / 300 loss: [-2.47906146e-17]
# Epoch 361: Accuracy 221 / 300 loss: [5.97594536e-17]
# Epoch 362: Accuracy 206 / 300 loss: [1.81260902e-17]
# Epoch 363: Accuracy 225 / 300 loss: [1.47274483e-17]
# Epoch 364: Accuracy 204 / 300 loss: [-1.86305761e-17]
# Epoch 365: Accuracy 221 / 300 loss: [-3.04461671e-17]
# Epoch 366: Accuracy 207 / 300 loss: [-2.51269385e-17]
# Epoch 367: Accuracy 220 / 300 loss: [-6.5707077e-17]
# Epoch 368: Accuracy 204 / 300 loss: [-4.70853515e-18]
# Epoch 369: Accuracy 221 / 300 loss: [-4.17749735e-17]
# Epoch 370: Accuracy 202 / 300 loss: [6.52822467e-17]
# Epoch 371: Accuracy 221 / 300 loss: [-3.54025199e-17]
# Epoch 372: Accuracy 201 / 300 loss: [3.92171414e-17]
# Epoch 373: Accuracy 220 / 300 loss: [-5.23957295e-18]
# Epoch 374: Accuracy 203 / 300 loss: [5.19620486e-17]
# Epoch 375: Accuracy 222 / 300 loss: [-1.88341406e-17]
# Epoch 376: Accuracy 206 / 300 loss: [-3.7960352e-17]
# Epoch 377: Accuracy 223 / 300 loss: [7.00969894e-17]
# Epoch 378: Accuracy 203 / 300 loss: [6.24854477e-18]
# Epoch 379: Accuracy 222 / 300 loss: [1.34529576e-17]
# Epoch 380: Accuracy 206 / 300 loss: [2.26576127e-18]
# Epoch 381: Accuracy 219 / 300 loss: [-1.4161008e-18]
# Epoch 382: Accuracy 208 / 300 loss: [-3.97393286e-18]
# Epoch 383: Accuracy 219 / 300 loss: [4.70145465e-17]
# Epoch 384: Accuracy 213 / 300 loss: [-4.60232759e-18]
# Epoch 385: Accuracy 216 / 300 loss: [9.98351062e-18]
# Epoch 386: Accuracy 217 / 300 loss: [-2.88884563e-17]
# Epoch 387: Accuracy 220 / 300 loss: [-1.39485928e-17]
# Epoch 388: Accuracy 215 / 300 loss: [-2.40737135e-18]
# Epoch 389: Accuracy 218 / 300 loss: [1.77366625e-17]
# Epoch 390: Accuracy 217 / 300 loss: [2.6144761e-17]
# Epoch 391: Accuracy 217 / 300 loss: [3.79515014e-17]
# Epoch 392: Accuracy 213 / 300 loss: [8.33729344e-18]
# Epoch 393: Accuracy 221 / 300 loss: [2.19495623e-17]
# Epoch 394: Accuracy 213 / 300 loss: [2.33656631e-17]
# Epoch 395: Accuracy 221 / 300 loss: [-2.51357891e-17]
# Epoch 396: Accuracy 209 / 300 loss: [-2.94017928e-17]
# Epoch 397: Accuracy 220 / 300 loss: [-3.66770106e-17]
# Epoch 398: Accuracy 206 / 300 loss: [5.56527613e-17]
# Epoch 399: Accuracy 221 / 300 loss: [-4.27662441e-17]
# Epoch 400: Accuracy 205 / 300 loss: [2.87556968e-17]
# Epoch 401: Accuracy 224 / 300 loss: [-1.04791459e-17]
# Epoch 402: Accuracy 207 / 300 loss: [3.08709974e-17]
# Epoch 403: Accuracy 224 / 300 loss: [-4.53152255e-17]
# Epoch 404: Accuracy 208 / 300 loss: [-4.7527883e-18]
# Epoch 405: Accuracy 220 / 300 loss: [2.1241512e-18]
# Epoch 406: Accuracy 204 / 300 loss: [-1.94758113e-17]
# Epoch 407: Accuracy 220 / 300 loss: [7.08050398e-18]
# Epoch 408: Accuracy 207 / 300 loss: [-5.73919101e-17]
# Epoch 409: Accuracy 222 / 300 loss: [-3.93676021e-17]
# Epoch 410: Accuracy 205 / 300 loss: [-1.85155179e-17]
# Epoch 455: Accuracy 224 / 300 loss: [3.59689602e-17]
# Epoch 456: Accuracy 207 / 300 loss: [-2.98930028e-17]
# Epoch 457: Accuracy 221 / 300 loss: [-2.81804059e-17]
# Epoch 458: Accuracy 205 / 300 loss: [-1.08331711e-17]
# Epoch 459: Accuracy 220 / 300 loss: [2.21619775e-17]
# Epoch 460: Accuracy 206 / 300 loss: [1.37583043e-17]
# Epoch 461: Accuracy 220 / 300 loss: [-9.34626526e-18]
# Epoch 462: Accuracy 208 / 300 loss: [-2.64987862e-17]
# Epoch 463: Accuracy 220 / 300 loss: [-2.90300663e-18]
# Epoch 464: Accuracy 209 / 300 loss: [6.59371933e-18]
# Epoch 465: Accuracy 221 / 300 loss: [-3.00213369e-17]
# Epoch 466: Accuracy 212 / 300 loss: [-1.4161008e-19]
# Epoch 467: Accuracy 219 / 300 loss: [-4.99175531e-17]
# Epoch 468: Accuracy 215 / 300 loss: [-3.554413e-17]
# Epoch 469: Accuracy 219 / 300 loss: [-1.43734231e-17]
# Epoch 470: Accuracy 215 / 300 loss: [-3.62875829e-17]
# Epoch 471: Accuracy 219 / 300 loss: [7.96556698e-18]
# Epoch 472: Accuracy 215 / 300 loss: [4.83244397e-18]
# Epoch 473: Accuracy 219 / 300 loss: [1.96838011e-17]
# Epoch 474: Accuracy 216 / 300 loss: [1.8179194e-17]
# Epoch 475: Accuracy 219 / 300 loss: [-4.81474271e-18]
# Epoch 476: Accuracy 215 / 300 loss: [-9.0630451e-18]
# Epoch 477: Accuracy 220 / 300 loss: [-2.83220159e-17]
# Epoch 478: Accuracy 216 / 300 loss: [1.77101106e-17]
# Epoch 479: Accuracy 221 / 300 loss: [-2.10290968e-17]
# Epoch 480: Accuracy 209 / 300 loss: [-3.01009926e-17]
# Epoch 481: Accuracy 220 / 300 loss: [1.35237626e-17]
# Epoch 482: Accuracy 209 / 300 loss: [3.82347215e-18]
# Epoch 483: Accuracy 222 / 300 loss: [-2.50649841e-17]
# Epoch 484: Accuracy 208 / 300 loss: [-3.07338126e-17]
# Epoch 485: Accuracy 224 / 300 loss: [-4.81474271e-17]
# Epoch 486: Accuracy 208 / 300 loss: [2.92424815e-17]
# Epoch 487: Accuracy 225 / 300 loss: [-3.78098913e-17]
# Epoch 488: Accuracy 207 / 300 loss: [-1.2461687e-17]
# Epoch 489: Accuracy 223 / 300 loss: [-3.554413e-17]
# Epoch 490: Accuracy 204 / 300 loss: [-2.21951673e-17]
# Epoch 491: Accuracy 223 / 300 loss: [1.98254112e-17]
# Epoch 492: Accuracy 206 / 300 loss: [5.94430436e-17]
# Epoch 493: Accuracy 223 / 300 loss: [-3.11542175e-17]
# Epoch 494: Accuracy 206 / 300 loss: [-4.40031196e-17]
# Epoch 495: Accuracy 221 / 300 loss: [-2.69059151e-18]
# Epoch 496: Accuracy 207 / 300 loss: [-3.44201e-17]
# Epoch 497: Accuracy 222 / 300 loss: [-9.98351062e-18]
# Epoch 498: Accuracy 207 / 300 loss: [-1.04747206e-17]
# Epoch 499: Accuracy 220 / 300 loss: [3.22870982e-17]
# Epoch 500: Accuracy 209 / 300 loss: [-1.35945676e-17]
# Epoch 501: Accuracy 219 / 300 loss: [1.69932096e-18]
# Epoch 502: Accuracy 209 / 300 loss: [3.52255073e-18]
# Epoch 503: Accuracy 222 / 300 loss: [1.42672155e-17]
# Epoch 504: Accuracy 213 / 300 loss: [-8.07177454e-18]
# Epoch 505: Accuracy 221 / 300 loss: [-1.35945676e-17]
# Epoch 506: Accuracy 215 / 300 loss: [2.45781995e-17]
# Epoch 507: Accuracy 221 / 300 loss: [3.69602308e-17]
# Epoch 508: Accuracy 216 / 300 loss: [-9.69143983e-18]
# Epoch 509: Accuracy 219 / 300 loss: [1.16828316e-17]
# Epoch 510: Accuracy 215 / 300 loss: [-4.56692507e-18]
# Epoch 511: Accuracy 221 / 300 loss: [-1.91173608e-18]
# Epoch 512: Accuracy 213 / 300 loss: [-1.47982533e-17]
# Epoch 513: Accuracy 221 / 300 loss: [-1.64975743e-17]
# Epoch 514: Accuracy 214 / 300 loss: [-2.47817639e-18]
# Epoch 515: Accuracy 221 / 300 loss: [1.71348196e-17]
# Epoch 516: Accuracy 214 / 300 loss: [1.70020602e-17]
# Epoch 517: Accuracy 221 / 300 loss: [9.45247282e-18]
# Epoch 518: Accuracy 215 / 300 loss: [-1.53381418e-17]
# Epoch 519: Accuracy 221 / 300 loss: [-2.1241512e-19]
# Epoch 520: Accuracy 215 / 300 loss: [1.35326132e-17]
# Epoch 521: Accuracy 221 / 300 loss: [1.26741021e-17]
# Epoch 522: Accuracy 216 / 300 loss: [-1.34529576e-17]
# Epoch 523: Accuracy 221 / 300 loss: [2.87468462e-17]
# Epoch 524: Accuracy 216 / 300 loss: [1.69932096e-17]
# Epoch 525: Accuracy 221 / 300 loss: [-3.68186207e-17]
# Epoch 526: Accuracy 216 / 300 loss: [2.27992228e-17]
# Epoch 527: Accuracy 221 / 300 loss: [-1.770126e-18]
# Epoch 528: Accuracy 212 / 300 loss: [5.5157126e-17]
# Epoch 529: Accuracy 221 / 300 loss: [-2.01086313e-17]
# Epoch 530: Accuracy 209 / 300 loss: [8.91258439e-18]
# Epoch 531: Accuracy 220 / 300 loss: [-4.38991247e-18]
# Epoch 532: Accuracy 209 / 300 loss: [-9.29316148e-19]
# Epoch 533: Accuracy 221 / 300 loss: [2.50649841e-17]
# Epoch 534: Accuracy 210 / 300 loss: [-1.64179186e-17]
# Epoch 535: Accuracy 221 / 300 loss: [2.4923374e-17]
# Epoch 536: Accuracy 209 / 300 loss: [-5.02760036e-17]
# Epoch 537: Accuracy 223 / 300 loss: [-2.90300663e-18]
# Epoch 538: Accuracy 209 / 300 loss: [-5.43428681e-17]
# Epoch 539: Accuracy 223 / 300 loss: [3.25703183e-17]
# Epoch 540: Accuracy 207 / 300 loss: [-9.68612945e-17]
# Epoch 541: Accuracy 224 / 300 loss: [1.27449072e-18]
# Epoch 542: Accuracy 207 / 300 loss: [-6.01842839e-18]
# Epoch 543: Accuracy 222 / 300 loss: [-5.66440319e-19]
# Epoch 589: Accuracy 222 / 300 loss: [1.66391844e-17]
# Epoch 590: Accuracy 206 / 300 loss: [-1.0368513e-17]
# Epoch 591: Accuracy 221 / 300 loss: [-7.15130902e-18]
# Epoch 592: Accuracy 207 / 300 loss: [-4.71893464e-17]
# Epoch 593: Accuracy 221 / 300 loss: [2.4852569e-17]
# Epoch 594: Accuracy 207 / 300 loss: [1.02999206e-17]
# Epoch 595: Accuracy 220 / 300 loss: [-2.35780783e-17]
# Epoch 596: Accuracy 207 / 300 loss: [3.68186207e-18]
# Epoch 597: Accuracy 221 / 300 loss: [3.83763316e-17]
# Epoch 598: Accuracy 211 / 300 loss: [4.92803077e-17]
# Epoch 599: Accuracy 220 / 300 loss: [-1.10101837e-17]
# Epoch 600: Accuracy 211 / 300 loss: [3.65221246e-17]
# Epoch 601: Accuracy 222 / 300 loss: [-2.23743926e-17]
# Epoch 602: Accuracy 212 / 300 loss: [-7.57613926e-18]
# Epoch 603: Accuracy 221 / 300 loss: [2.93840915e-18]
# Epoch 604: Accuracy 213 / 300 loss: [-2.90300663e-17]
# Epoch 605: Accuracy 221 / 300 loss: [1.784287e-17]
# Epoch 606: Accuracy 216 / 300 loss: [1.54974531e-17]
# Epoch 607: Accuracy 220 / 300 loss: [-3.75620736e-17]
# Epoch 608: Accuracy 218 / 300 loss: [2.23035875e-18]
# Epoch 609: Accuracy 219 / 300 loss: [-6.62027122e-18]
# Epoch 610: Accuracy 218 / 300 loss: [-1.72233259e-17]
# Epoch 611: Accuracy 218 / 300 loss: [-5.32011368e-17]
# Epoch 612: Accuracy 218 / 300 loss: [1.35237626e-17]
# Epoch 613: Accuracy 220 / 300 loss: [-1.44265269e-17]
# Epoch 614: Accuracy 216 / 300 loss: [1.59930884e-17]
# Epoch 615: Accuracy 220 / 300 loss: [-2.83220159e-18]
# Epoch 616: Accuracy 220 / 300 loss: [-3.82347215e-18]
# Epoch 617: Accuracy 220 / 300 loss: [-1.0620756e-18]
# Epoch 618: Accuracy 220 / 300 loss: [-9.73569298e-20]
# Epoch 619: Accuracy 220 / 300 loss: [5.09796287e-18]
# Epoch 620: Accuracy 218 / 300 loss: [1.84093104e-17]
# Epoch 621: Accuracy 222 / 300 loss: [2.97381167e-18]
# Epoch 622: Accuracy 214 / 300 loss: [-3.09418024e-17]
# Epoch 623: Accuracy 222 / 300 loss: [-3.44820544e-17]
# Epoch 624: Accuracy 211 / 300 loss: [2.03918515e-17]
# Epoch 625: Accuracy 221 / 300 loss: [-3.89427719e-18]
# Epoch 626: Accuracy 211 / 300 loss: [-1.48690584e-18]
# Epoch 627: Accuracy 221 / 300 loss: [2.27992228e-17]
# Epoch 628: Accuracy 210 / 300 loss: [-8.43022506e-18]
# Epoch 629: Accuracy 220 / 300 loss: [1.0691561e-17]
# Epoch 630: Accuracy 208 / 300 loss: [-2.35050606e-17]
# Epoch 631: Accuracy 222 / 300 loss: [6.79728382e-18]
# Epoch 632: Accuracy 209 / 300 loss: [4.82890372e-17]
# Epoch 633: Accuracy 225 / 300 loss: [1.6072744e-17]
# Epoch 634: Accuracy 208 / 300 loss: [-2.94548966e-17]
# Epoch 635: Accuracy 222 / 300 loss: [4.63773011e-17]
# Epoch 636: Accuracy 208 / 300 loss: [-1.55074101e-17]
# Epoch 637: Accuracy 221 / 300 loss: [-6.0467504e-17]
# Epoch 638: Accuracy 207 / 300 loss: [1.04404244e-17]
# Epoch 639: Accuracy 221 / 300 loss: [-1.64975743e-17]
# Epoch 640: Accuracy 208 / 300 loss: [6.23792401e-17]
# Epoch 641: Accuracy 221 / 300 loss: [1.37361777e-17]
# Epoch 642: Accuracy 210 / 300 loss: [-6.26536096e-17]
# Epoch 643: Accuracy 222 / 300 loss: [4.81474271e-17]
# Epoch 644: Accuracy 211 / 300 loss: [4.07128979e-17]
# Epoch 645: Accuracy 222 / 300 loss: [-4.60232759e-17]
# Epoch 646: Accuracy 213 / 300 loss: [-1.35945676e-17]
# Epoch 647: Accuracy 221 / 300 loss: [-1.19306492e-17]
# Epoch 648: Accuracy 215 / 300 loss: [-1.07623661e-17]
# Epoch 649: Accuracy 221 / 300 loss: [-1.21430643e-17]
# Epoch 650: Accuracy 216 / 300 loss: [-1.48690584e-17]
# Epoch 651: Accuracy 221 / 300 loss: [2.14539271e-17]
# Epoch 652: Accuracy 218 / 300 loss: [2.44985438e-17]
# Epoch 653: Accuracy 221 / 300 loss: [5.84141579e-18]
# Epoch 654: Accuracy 220 / 300 loss: [-1.8488966e-17]
# Epoch 655: Accuracy 217 / 300 loss: [1.38158334e-17]
# Epoch 656: Accuracy 220 / 300 loss: [-1.98254112e-18]
# Epoch 657: Accuracy 218 / 300 loss: [-1.41256054e-17]
# Epoch 658: Accuracy 217 / 300 loss: [2.20203674e-17]
# Epoch 659: Accuracy 219 / 300 loss: [3.09772049e-17]
# Epoch 660: Accuracy 219 / 300 loss: [-3.0233752e-17]
# Epoch 661: Accuracy 220 / 300 loss: [-2.15247321e-17]
# Epoch 662: Accuracy 219 / 300 loss: [-2.03918515e-17]
# Epoch 663: Accuracy 220 / 300 loss: [-2.32948581e-17]
# Epoch 664: Accuracy 218 / 300 loss: [3.26588246e-18]
# Epoch 665: Accuracy 221 / 300 loss: [-4.68906376e-17]
# Epoch 666: Accuracy 220 / 300 loss: [1.48690584e-17]
# Epoch 667: Accuracy 221 / 300 loss: [-1.5931134e-17]
# Epoch 668: Accuracy 220 / 300 loss: [-3.46944695e-18]
# Epoch 669: Accuracy 220 / 300 loss: [1.44973319e-17]
# Epoch 670: Accuracy 219 / 300 loss: [2.10822006e-17]
# Epoch 671: Accuracy 221 / 300 loss: [-8.85062998e-19]
# Epoch 672: Accuracy 216 / 300 loss: [2.8392821e-17]
# Epoch 673: Accuracy 222 / 300 loss: [3.29243435e-18]
# Epoch 674: Accuracy 210 / 300 loss: [2.33656631e-18]
# Epoch 675: Accuracy 222 / 300 loss: [-2.79679907e-17]
# Epoch 676: Accuracy 209 / 300 loss: [2.69413177e-17]
# Epoch 677: Accuracy 222 / 300 loss: [2.34364682e-17]
# Epoch 678: Accuracy 208 / 300 loss: [-2.65076368e-18]
# Epoch 679: Accuracy 222 / 300 loss: [-4.04296777e-17]
# Epoch 680: Accuracy 209 / 300 loss: [-4.07837029e-17]
# Epoch 681: Accuracy 225 / 300 loss: [9.13385014e-18]
# Epoch 682: Accuracy 208 / 300 loss: [4.33680869e-18]
# Epoch 683: Accuracy 225 / 300 loss: [3.10834125e-17]
# Epoch 684: Accuracy 208 / 300 loss: [5.66661584e-18]
# Epoch 685: Accuracy 223 / 300 loss: [1.27449072e-18]
# Epoch 686: Accuracy 208 / 300 loss: [6.52313556e-17]
# Epoch 687: Accuracy 222 / 300 loss: [-2.38612984e-17]
# Epoch 688: Accuracy 206 / 300 loss: [-9.5365538e-19]
# Epoch 689: Accuracy 221 / 300 loss: [5.02715783e-18]
# Epoch 690: Accuracy 210 / 300 loss: [-5.51172982e-17]
# Epoch 691: Accuracy 221 / 300 loss: [1.69932096e-18]
# Epoch 692: Accuracy 212 / 300 loss: [1.83296547e-17]
# Epoch 693: Accuracy 220 / 300 loss: [-2.42153236e-17]
# Epoch 694: Accuracy 215 / 300 loss: [-2.1790251e-17]
# Epoch 695: Accuracy 221 / 300 loss: [-6.65567374e-18]
# Epoch 696: Accuracy 216 / 300 loss: [-3.11542175e-18]
# Epoch 697: Accuracy 221 / 300 loss: [9.02764258e-18]
# Epoch 698: Accuracy 217 / 300 loss: [-2.09671424e-17]
# Epoch 699: Accuracy 219 / 300 loss: [-1.69755083e-17]
# Epoch 700: Accuracy 217 / 300 loss: [-1.36122689e-17]
# Epoch 701: Accuracy 221 / 300 loss: [-1.5116876e-17]
# Epoch 702: Accuracy 220 / 300 loss: [-2.33656631e-17]
# Epoch 703: Accuracy 220 / 300 loss: [-8.73557179e-18]
# Epoch 704: Accuracy 217 / 300 loss: [-6.1688891e-18]
# Epoch 705: Accuracy 220 / 300 loss: [-2.01440338e-17]
# Epoch 706: Accuracy 218 / 300 loss: [-1.71525209e-17]
# Epoch 707: Accuracy 220 / 300 loss: [-9.82419928e-18]
# Epoch 708: Accuracy 218 / 300 loss: [-6.27509666e-18]
# Epoch 709: Accuracy 221 / 300 loss: [4.13501433e-17]
# Epoch 710: Accuracy 219 / 300 loss: [-6.04498028e-18]
# Epoch 711: Accuracy 221 / 300 loss: [-3.42165355e-17]
# Epoch 712: Accuracy 219 / 300 loss: [-3.52609098e-17]
# Epoch 713: Accuracy 219 / 300 loss: [-3.24641108e-17]
# Epoch 714: Accuracy 217 / 300 loss: [4.16510647e-17]
# Epoch 715: Accuracy 220 / 300 loss: [-2.29319823e-17]
# Epoch 716: Accuracy 219 / 300 loss: [-1.53115899e-17]
# Epoch 717: Accuracy 220 / 300 loss: [1.334675e-17]
# Epoch 718: Accuracy 218 / 300 loss: [-7.05395209e-18]
# Epoch 719: Accuracy 220 / 300 loss: [-1.47628508e-17]
# Epoch 720: Accuracy 218 / 300 loss: [-2.46401539e-17]
# Epoch 721: Accuracy 221 / 300 loss: [-6.26624603e-18]
# Epoch 722: Accuracy 220 / 300 loss: [1.26386996e-17]
# Epoch 723: Accuracy 221 / 300 loss: [2.81627046e-17]
# Epoch 724: Accuracy 220 / 300 loss: [1.07889179e-17]
# Epoch 725: Accuracy 221 / 300 loss: [-4.31910743e-18]
# Epoch 726: Accuracy 219 / 300 loss: [8.85062998e-21]
# Epoch 727: Accuracy 222 / 300 loss: [2.78794844e-17]
# Epoch 728: Accuracy 219 / 300 loss: [-3.50484947e-18]
# Epoch 729: Accuracy 222 / 300 loss: [-3.34553813e-18]
# Epoch 730: Accuracy 219 / 300 loss: [-1.657723e-17]
# Epoch 731: Accuracy 222 / 300 loss: [-2.74369529e-18]
# Epoch 732: Accuracy 218 / 300 loss: [1.01516726e-17]
# Epoch 733: Accuracy 220 / 300 loss: [-2.72599403e-17]
# Epoch 734: Accuracy 218 / 300 loss: [-2.09582918e-17]
# Epoch 735: Accuracy 220 / 300 loss: [-1.10809887e-17]
# Epoch 736: Accuracy 218 / 300 loss: [1.57895239e-17]
# Epoch 737: Accuracy 220 / 300 loss: [-4.60586784e-17]
# Epoch 738: Accuracy 218 / 300 loss: [-1.03375358e-17]
# Epoch 739: Accuracy 220 / 300 loss: [2.86760411e-18]
# Epoch 740: Accuracy 218 / 300 loss: [4.45009675e-17]
# Epoch 741: Accuracy 220 / 300 loss: [2.84105222e-17]
# Epoch 742: Accuracy 219 / 300 loss: [1.8727933e-17]
# Epoch 743: Accuracy 221 / 300 loss: [8.12487832e-18]
# Epoch 744: Accuracy 219 / 300 loss: [3.25260652e-17]
# Epoch 745: Accuracy 222 / 300 loss: [-6.90349138e-19]
# Epoch 746: Accuracy 220 / 300 loss: [3.58450514e-18]
# Epoch 747: Accuracy 222 / 300 loss: [2.86760411e-18]
# Epoch 748: Accuracy 220 / 300 loss: [-1.0620756e-19]
# Epoch 749: Accuracy 221 / 300 loss: [-5.68210445e-18]
# Epoch 750: Accuracy 220 / 300 loss: [-1.1576624e-17]
# Epoch 751: Accuracy 221 / 300 loss: [-6.62735173e-17]
# Epoch 752: Accuracy 219 / 300 loss: [6.77958256e-18]
# Epoch 753: Accuracy 221 / 300 loss: [1.58249264e-17]
# Epoch 754: Accuracy 217 / 300 loss: [3.1371058e-17]
# Epoch 755: Accuracy 222 / 300 loss: [-3.43758468e-17]
# Epoch 756: Accuracy 213 / 300 loss: [1.77056853e-17]
# Epoch 757: Accuracy 222 / 300 loss: [3.04461671e-18]
# Epoch 758: Accuracy 211 / 300 loss: [-1.2067834e-17]
# Epoch 759: Accuracy 221 / 300 loss: [6.19898124e-17]
# Epoch 760: Accuracy 208 / 300 loss: [2.87114437e-17]
# Epoch 761: Accuracy 226 / 300 loss: [4.60232759e-19]
# Epoch 762: Accuracy 210 / 300 loss: [1.29219198e-17]
# Epoch 763: Accuracy 224 / 300 loss: [2.56668269e-17]
# Epoch 764: Accuracy 208 / 300 loss: [-4.59790227e-18]
# Epoch 765: Accuracy 222 / 300 loss: [2.54190093e-17]
# Epoch 766: Accuracy 209 / 300 loss: [-1.18764391e-17]
# Epoch 811: Accuracy 222 / 300 loss: [1.06561585e-17]
# Epoch 812: Accuracy 220 / 300 loss: [2.39055516e-17]
# Epoch 813: Accuracy 223 / 300 loss: [-8.81522746e-18]
# Epoch 814: Accuracy 219 / 300 loss: [-3.58804539e-17]
# Epoch 815: Accuracy 220 / 300 loss: [3.11542175e-18]
# Epoch 816: Accuracy 218 / 300 loss: [-9.6825892e-18]
# Epoch 817: Accuracy 220 / 300 loss: [1.48690584e-18]
# Epoch 818: Accuracy 217 / 300 loss: [-3.52786111e-17]
# Epoch 819: Accuracy 220 / 300 loss: [-1.64975743e-17]
# Epoch 820: Accuracy 218 / 300 loss: [6.434408e-18]
# Epoch 821: Accuracy 220 / 300 loss: [-3.02249014e-17]
# Epoch 822: Accuracy 219 / 300 loss: [-2.15955371e-17]
# Epoch 823: Accuracy 219 / 300 loss: [4.18546292e-17]
# Epoch 824: Accuracy 218 / 300 loss: [-1.73472348e-18]
# Epoch 825: Accuracy 219 / 300 loss: [-5.50509185e-18]
# Epoch 826: Accuracy 217 / 300 loss: [-2.78529325e-17]
# Epoch 827: Accuracy 221 / 300 loss: [3.73496585e-17]
# Epoch 828: Accuracy 217 / 300 loss: [-4.74393767e-18]
# Epoch 829: Accuracy 220 / 300 loss: [-3.02691545e-17]
# Epoch 830: Accuracy 218 / 300 loss: [2.58792421e-17]
# Epoch 831: Accuracy 220 / 300 loss: [2.86760411e-18]
# Epoch 832: Accuracy 218 / 300 loss: [-1.98254112e-18]
# Epoch 833: Accuracy 219 / 300 loss: [-4.49700509e-17]
# Epoch 834: Accuracy 220 / 300 loss: [-1.93651784e-17]
# Epoch 835: Accuracy 218 / 300 loss: [-3.52609098e-17]
# Epoch 836: Accuracy 222 / 300 loss: [-9.38166778e-18]
# Epoch 837: Accuracy 220 / 300 loss: [1.32936462e-17]
# Epoch 838: Accuracy 222 / 300 loss: [8.65591612e-18]
# Epoch 839: Accuracy 220 / 300 loss: [-5.62988573e-17]
# Epoch 840: Accuracy 222 / 300 loss: [1.43380206e-17]
# Epoch 841: Accuracy 220 / 300 loss: [-2.58349889e-17]
# Epoch 842: Accuracy 222 / 300 loss: [5.11566413e-18]
# Epoch 843: Accuracy 219 / 300 loss: [-4.12793382e-17]
# Epoch 844: Accuracy 222 / 300 loss: [-3.08355948e-17]
# Epoch 845: Accuracy 219 / 300 loss: [3.60928691e-17]
# Epoch 846: Accuracy 222 / 300 loss: [2.60739559e-17]
# Epoch 847: Accuracy 219 / 300 loss: [-7.31947099e-18]
# Epoch 848: Accuracy 222 / 300 loss: [-4.49612003e-18]
# Epoch 849: Accuracy 220 / 300 loss: [6.40785611e-18]
# Epoch 850: Accuracy 222 / 300 loss: [5.13336539e-19]
# Epoch 851: Accuracy 220 / 300 loss: [1.72587285e-18]
# Epoch 852: Accuracy 222 / 300 loss: [-3.28712397e-17]
# Epoch 853: Accuracy 220 / 300 loss: [6.48751177e-18]
# Epoch 854: Accuracy 222 / 300 loss: [5.60244878e-17]
# Epoch 855: Accuracy 220 / 300 loss: [-1.72056247e-17]
# Epoch 856: Accuracy 222 / 300 loss: [1.43734231e-17]
# Epoch 857: Accuracy 220 / 300 loss: [-5.24399826e-18]
# Epoch 858: Accuracy 221 / 300 loss: [4.47487852e-17]
# Epoch 859: Accuracy 219 / 300 loss: [1.62895845e-17]
# Epoch 860: Accuracy 220 / 300 loss: [-4.71384553e-17]
# Epoch 861: Accuracy 220 / 300 loss: [3.09772049e-17]
# Epoch 862: Accuracy 222 / 300 loss: [-2.61978647e-17]
# Epoch 863: Accuracy 211 / 300 loss: [1.27404819e-17]
# Epoch 864: Accuracy 222 / 300 loss: [4.9846748e-17]
# Epoch 865: Accuracy 208 / 300 loss: [4.66583086e-17]
# Epoch 866: Accuracy 226 / 300 loss: [7.22211406e-18]
# Epoch 867: Accuracy 207 / 300 loss: [-1.4157689e-17]
# Epoch 868: Accuracy 221 / 300 loss: [3.48360796e-17]
# Epoch 869: Accuracy 211 / 300 loss: [-4.34754008e-17]
# Epoch 870: Accuracy 224 / 300 loss: [-5.00591632e-17]
# Epoch 871: Accuracy 213 / 300 loss: [8.85394897e-18]
# Epoch 872: Accuracy 222 / 300 loss: [-1.41964105e-17]
# Epoch 873: Accuracy 211 / 300 loss: [-1.26729958e-17]
# Epoch 874: Accuracy 222 / 300 loss: [2.92424815e-17]
# Epoch 875: Accuracy 211 / 300 loss: [-3.95092122e-17]
# Epoch 876: Accuracy 221 / 300 loss: [1.13288064e-17]
# Epoch 877: Accuracy 210 / 300 loss: [6.19765364e-18]
# Epoch 878: Accuracy 219 / 300 loss: [9.7710955e-18]
# Epoch 879: Accuracy 211 / 300 loss: [4.58473696e-17]
# Epoch 880: Accuracy 221 / 300 loss: [-2.69059151e-18]
# Epoch 881: Accuracy 211 / 300 loss: [-1.65019996e-17]
# Epoch 882: Accuracy 222 / 300 loss: [4.38991247e-18]
# Epoch 883: Accuracy 212 / 300 loss: [-6.72647878e-18]
# Epoch 884: Accuracy 220 / 300 loss: [-2.82158084e-17]
# Epoch 885: Accuracy 216 / 300 loss: [-3.28513258e-17]
# Epoch 886: Accuracy 222 / 300 loss: [1.09128268e-17]
# Epoch 887: Accuracy 219 / 300 loss: [-1.29042185e-17]
# Epoch 888: Accuracy 221 / 300 loss: [-4.24830239e-19]
# Epoch 889: Accuracy 219 / 300 loss: [-5.54049437e-18]
# Epoch 890: Accuracy 221 / 300 loss: [-1.25147908e-17]
# Epoch 891: Accuracy 219 / 300 loss: [-9.4480475e-18]
# Epoch 892: Accuracy 222 / 300 loss: [1.45061825e-17]
# Epoch 893: Accuracy 217 / 300 loss: [-6.51406366e-18]
# Epoch 894: Accuracy 221 / 300 loss: [2.05688641e-17]
# Epoch 895: Accuracy 218 / 300 loss: [1.23599048e-17]
# Epoch 896: Accuracy 221 / 300 loss: [1.21961681e-17]
# Epoch 897: Accuracy 218 / 300 loss: [1.69932096e-17]
# Epoch 898: Accuracy 221 / 300 loss: [1.75242474e-17]
# Epoch 899: Accuracy 219 / 300 loss: [-4.053146e-17]
# Epoch 4967: Accuracy 221 / 300 loss: [-4.82536346e-17]
# Epoch 4968: Accuracy 227 / 300 loss: [-2.02767933e-17]
# Epoch 4969: Accuracy 222 / 300 loss: [-1.49376507e-17]
# Epoch 4970: Accuracy 226 / 300 loss: [7.89918726e-18]
# Epoch 4971: Accuracy 221 / 300 loss: [-4.70986274e-17]
# Epoch 4972: Accuracy 227 / 300 loss: [3.17029566e-17]
# Epoch 4973: Accuracy 222 / 300 loss: [7.92131383e-17]
# Epoch 4974: Accuracy 226 / 300 loss: [6.0467504e-17]
# Epoch 4975: Accuracy 222 / 300 loss: [-2.26133596e-18]
# Epoch 4976: Accuracy 227 / 300 loss: [5.79716264e-18]
# Epoch 4977: Accuracy 222 / 300 loss: [3.39465913e-17]
# Epoch 4978: Accuracy 226 / 300 loss: [1.92633962e-17]
# Epoch 4979: Accuracy 221 / 300 loss: [2.50605588e-17]
# Epoch 4980: Accuracy 227 / 300 loss: [1.47318736e-17]
# Epoch 4981: Accuracy 222 / 300 loss: [-1.20468137e-17]
# Epoch 4982: Accuracy 226 / 300 loss: [1.46035395e-17]
# Epoch 4983: Accuracy 221 / 300 loss: [8.49660478e-18]
# Epoch 4984: Accuracy 227 / 300 loss: [2.67023506e-17]
# Epoch 4985: Accuracy 222 / 300 loss: [-6.14565619e-19]
# Epoch 4986: Accuracy 226 / 300 loss: [-2.80741983e-17]
# Epoch 4987: Accuracy 221 / 300 loss: [1.01206954e-17]
# Epoch 4988: Accuracy 227 / 300 loss: [1.52319342e-17]
# Epoch 4989: Accuracy 222 / 300 loss: [7.04344197e-18]
# Epoch 4990: Accuracy 226 / 300 loss: [-4.09164624e-17]
# Epoch 4991: Accuracy 221 / 300 loss: [-1.02783472e-17]
# Epoch 4992: Accuracy 227 / 300 loss: [-3.63052842e-17]
# Epoch 4993: Accuracy 222 / 300 loss: [2.22759293e-18]
# Epoch 4994: Accuracy 226 / 300 loss: [-7.22653938e-18]
# Epoch 4995: Accuracy 221 / 300 loss: [-2.73307454e-17]
# Epoch 4996: Accuracy 227 / 300 loss: [2.13875473e-17]
# Epoch 4997: Accuracy 222 / 300 loss: [-5.18292892e-17]
# Epoch 4998: Accuracy 227 / 300 loss: [-8.75327305e-18]
# Epoch 4999: Accuracy 222 / 300 loss: [4.57632886e-18]
# Model with highest accuracy 0.7633333333333333 achieved at epoch 17

# %%
losses_training = nnet_2.losses
accuracy_training = nnet_2.accuracies
visualize_cost_accuracy_curves(accuracy_training, losses_training)
visualize_posterior(nnet_2)
# Out:
# best_accuracy: 0.7633333333333333 achieved at epoch: 17

# %% [markdown]
# <a id='Compare'></a>
# ## Compare the two networks below:

# %% [markdown]
# Answer:
#
# From the tests above we can see that the first network had a better accuracy. However it took a lot longer to compute and it is much slower. A factor for this is the higher learning rate.
#
# In the 2nd test with a much smaller learning rate the accuracy hit its peak at the epoch 17 much sooner than the first example.
#
# .
#
#
# However, these tests might not be fully accurate:
#
# Having a smaller learning rate enables the network to converge much better and avoids overshooting. Overall relu should give a better result in faster times.
